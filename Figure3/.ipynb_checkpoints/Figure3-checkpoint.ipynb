# %% [markdown]
# ### FIGURE 3 - Clasen et al

# %%
import pandas as pd
import plotly.express as px
from collections import defaultdict
import plotly

# %%
def getCarbonCount(comp):
    if 'C' in comp:
        if 'H' in comp:
            carbon = comp.split('H')[0].replace('C','')
            try:
                carbon = int(carbon)
            except ValueError:
                carbon = 1
        else:
            carbon = 1
    else:
        carbon = 0 
    return carbon

# %%
def setPlotFont(fig):
    fig = fig.update_layout(font=dict(size=12,family='Arial',color="black"))
    return fig

# %%
def influx(diet_df,models):
    groups = ['Carbohydrate','Lipid','Amino Acid']
    skip =  ['starch structure 2[s]','O2[s]','sucrose[s]']
    d = []
    for model in models:
        total = 0
        counts = {}
        for group in groups:
            count = 0
            sub_df = diet_df[diet_df['Group'] == group]
            for index,row in sub_df.iterrows():
                if str(row['Metabolite']) not in skip:
                    carbon = row['Composition'].split('H')[0].replace('C','')
                    moleFlux = float(carbon) * float(row[model])
                    count += moleFlux
            counts[group] = count
        for count in counts:
            ratio = counts[count]
            d.append({'Model' : 'IN_'+model,
                      'Group' : count,
                      'Cmoles' : ratio})
    df = pd.DataFrame(d)
    return df

# %%
def efflux(fba,mets_df,models):
    composition = dict(zip(mets_df.index,mets_df['COMPOSITION']))
    composition['LDL[s]'] = 'C36720H2XXX'
    biomassC = {}
    otherC = defaultdict(dict)
    Cin = defaultdict(dict)
    fluxIn = defaultdict(dict)
    fluxOut = defaultdict(dict)
    modelTotals = {}
    for model in models:
        carbonIn = 0
        carbonOut = 0
        for index,row in fba.iterrows():
            if index == 'HMR_5265':
                apoBFlux = row[model]
            if row['SUBSYSTEM'] == 'Exchange reactions' and row[model] != 0:
                if '_IN_' in index:
                    met = row['EQUATION'].replace(' => ','').strip()
                    c = getCarbonCount(str(composition[met]))
                    carbonIn += abs(row[model]) * c
                    fluxIn[model][met] = abs(row[model])
                elif '_OUT_' in index:
                    met = row['EQUATION'].replace(' => ','').strip()
                    c = getCarbonCount(str(composition[met]))
                    carbonOut += abs(row[model]) * c
                    fluxOut[model][met] = abs(row[model])
                    if met != 'CO2[s]':
                        otherC[model][met] = abs(row[model]) * c
                elif '_BOTH_' in index:    
                    met = row['EQUATION'].replace(' <=> ','').strip()
                    c = getCarbonCount(str(composition[met]))
                    if row[model] < 0:
                        carbonOut += abs(row[model]) * c
                        otherC[model][met] = abs(row[model]) * c
                        fluxOut[model][met] = abs(row[model])
                    elif row[model] > 0:
                        carbonIn += abs(row[model]) * c
                        fluxIn[model][met] = abs(row[model])
                    else:
                        print(met)
                else:
                    print('CHECK!!!!') 
                #if c == 0 :
                #    print(met)
        carbonIn += apoBFlux * 22282
        netcarbon = carbonIn - carbonOut
        biomassC[model] = netcarbon
        modelTotals[model] = carbonIn
    CO2 = {}
    for model in models:
        CO2[model] = fba.at['EXC_OUT_C00011[s]',model]
    d = []
    for model in biomassC:
        modelName = 'OUT_'+model
        d.append({'Model' : modelName,
                  'Cmoles' : biomassC[model], 
                  'Metabolite' : 'biomass',
                  'Group' : 'Biomass'})
        d.append({'Model' : modelName,
                  'Cmoles' : CO2[model], 
                  'Metabolite' : 'CO2',
                  'Group' : 'CO2'})
        for met in otherC[model]:
            if 'glycerol' in met:
                d.append({'Model' : modelName,
                          'Cmoles' : otherC[model][met], 
                          'Metabolite' : met,
                          'Group' : 'glycerol'})
            elif 'succinate' in met: 
                d.append({'Model' : modelName,
                          'Cmoles' : otherC[model][met], 
                          'Metabolite' : met,
                          'Group' : 'succinate'})
            else:
                d.append({'Model' : modelName,
                          'Cmoles' : otherC[model][met], 
                          'Metabolite' : met,
                          'Group' : 'Other metabolites'})
    df = pd.DataFrame(d)
    return df

# %%
fba = pd.read_excel('../Supplementary Tables.xlsx',sheet_name='Table S3',index_col='ID')
diet_df = pd.read_excel('../Supplementary Tables.xlsx',sheet_name = 'Table S2')
mets_df = pd.read_excel('../data/models/xlsx/genericLiverWD.xlsx',sheet_name = 'METS',index_col = 'ID')

# %%
INMODELS = ['CD','WD',
          'genericCD','genericWD',
          'CD_nonDEN_Liver_CD','CD_nonDEN_Liver_WD','CD_DEN_Liver_CD','CD_DEN_AdjLiver_WD','CD_DEN_Tumour_WD',
          'WD_nonDEN_Liver_CD','WD_nonDEN_Liver_WD','WD_DEN_Liver_CD','WD_DEN_AdjLiver_WD','WD_DEN_Tumour_WD']
INFLUX = influx(diet_df,INMODELS)

# %%
OUTMODELS = INMODELS[2:]
EFFLUX = efflux(fba,mets_df,OUTMODELS)

# %%
FINAL = pd.concat([INFLUX,EFFLUX],axis=0)

# %%
cols = plotly.colors.qualitative.Pastel[0:7] 
fig = px.bar(FINAL,
             x = 'Model',
             y = 'Cmoles',
             color= 'Group',
             template = 'none',
             category_orders={"Group": ['Carbohydrate','Lipid','Amino Acid','Sink reactions',
                                        'Biomass','CO2','glycerol','succinate','Other metabolites']},
             color_discrete_sequence=[cols[1],cols[2],cols[3],cols[6],
                                      'rgb(0,0,0)', 'rgb(82,82,82)', 'rgb(150,150,150)', 'rgb(189,189,189)',
                                      'rgb(230,230,230)'])
fig.update_layout(autosize = False,
                  width = 800,
                  height = 300,
                  xaxis_title='',
                  yaxis_title='Carbon flux (mmol/mouse/day)',
                  margin=dict(l=50,
                              r=20,
                              b=20,
                              t=20,
                              pad=4))
fig = setPlotFont(fig)
fig.update_layout(legend_traceorder="reversed")
fig.update_xaxes(showticklabels=False)
fig.update_xaxes(tickangle=90)
#fig.write_image('../v8/Figures/Figure3/Suppl/FigureS3B_1.pdf')
fig.show()
# Out:
# <div>                            <div id="62e66914-21c1-41fc-990b-a91f1fa6c5e0" class="plotly-graph-div" style="height:300px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62e66914-21c1-41fc-990b-a91f1fa6c5e0")) {                    Plotly.newPlot(                        "62e66914-21c1-41fc-990b-a91f1fa6c5e0",                        [{"alignmentgroup":"True","hovertemplate":"Group=Carbohydrate<br>Model=%{x}<br>Cmoles=%{y}<extra></extra>","legendgroup":"Carbohydrate","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Carbohydrate","offsetgroup":"Carbohydrate","orientation":"v","showlegend":true,"textposition":"auto","x":["IN_CD","IN_WD","IN_genericCD","IN_genericWD","IN_CD_nonDEN_Liver_CD","IN_CD_nonDEN_Liver_WD","IN_CD_DEN_Liver_CD","IN_CD_DEN_AdjLiver_WD","IN_CD_DEN_Tumour_WD","IN_WD_nonDEN_Liver_CD","IN_WD_nonDEN_Liver_WD","IN_WD_DEN_Liver_CD","IN_WD_DEN_AdjLiver_WD","IN_WD_DEN_Tumour_WD"],"xaxis":"x","y":[58.087820040000004,41.152761408,30.30968421,24.636176508,18.332511786,17.880186522,17.288552322,22.170905634000004,20.934105804000005,25.264964016,24.768805212,16.509820512,32.465121228,36.320039640000005],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Group=Lipid<br>Model=%{x}<br>Cmoles=%{y}<extra></extra>","legendgroup":"Lipid","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Lipid","offsetgroup":"Lipid","orientation":"v","showlegend":true,"textposition":"auto","x":["IN_CD","IN_WD","IN_genericCD","IN_genericWD","IN_CD_nonDEN_Liver_CD","IN_CD_nonDEN_Liver_WD","IN_CD_DEN_Liver_CD","IN_CD_DEN_AdjLiver_WD","IN_CD_DEN_Tumour_WD","IN_WD_nonDEN_Liver_CD","IN_WD_nonDEN_Liver_WD","IN_WD_DEN_Liver_CD","IN_WD_DEN_AdjLiver_WD","IN_WD_DEN_Tumour_WD"],"xaxis":"x","y":[8.158541432,34.228984813,2.989742732,5.242956368,2.97604562,2.97604562,2.97604562,2.97604562,2.97604562,14.122177826000001,14.122177826000001,14.122177826000001,14.122177826000001,14.122177826000001],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Group=Amino Acid<br>Model=%{x}<br>Cmoles=%{y}<extra></extra>","legendgroup":"Amino Acid","marker":{"color":"rgb(220, 176, 242)","pattern":{"shape":""}},"name":"Amino Acid","offsetgroup":"Amino Acid","orientation":"v","showlegend":true,"textposition":"auto","x":["IN_CD","IN_WD","IN_genericCD","IN_genericWD","IN_CD_nonDEN_Liver_CD","IN_CD_nonDEN_Liver_WD","IN_CD_DEN_Liver_CD","IN_CD_DEN_AdjLiver_WD","IN_CD_DEN_Tumour_WD","IN_WD_nonDEN_Liver_CD","IN_WD_nonDEN_Liver_WD","IN_WD_DEN_Liver_CD","IN_WD_DEN_AdjLiver_WD","IN_WD_DEN_Tumour_WD"],"xaxis":"x","y":[19.935097655000003,22.991449192999998,19.528187549000002,22.651743309999997,17.848931334,17.848933622,17.246562462,17.861833749,17.861852328,20.21978192,20.220220534,19.511775554,20.229611376999998,20.216917025],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Group=Biomass<br>Model=%{x}<br>Cmoles=%{y}<extra></extra>","legendgroup":"Biomass","marker":{"color":"rgb(0,0,0)","pattern":{"shape":""}},"name":"Biomass","offsetgroup":"Biomass","orientation":"v","showlegend":true,"textposition":"auto","x":["OUT_genericCD","OUT_genericWD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_WD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_Tumour_WD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_WD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_Tumour_WD"],"xaxis":"x","y":[36.358783900350815,44.858335245075054,19.048597638148145,19.04887338691573,18.17084611113188,20.220183463477,20.2215139027522,22.76147375216412,22.84192658835147,21.94229669493862,24.564424514061315,25.451800792841922],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Group=CO2<br>Model=%{x}<br>Cmoles=%{y}<extra></extra>","legendgroup":"CO2","marker":{"color":"rgb(82,82,82)","pattern":{"shape":" ...

# %%
others
# Out:
#                     Model              Group     Cmoles  \
# 2           OUT_genericCD  Other metabolites   0.570685
# 3           OUT_genericCD  Other metabolites   0.196359
# 4           OUT_genericCD  Other metabolites   2.368351
# 5           OUT_genericCD  Other metabolites   1.775808
# 6           OUT_genericCD  Other metabolites  25.969818
# ..                    ...                ...        ...
# 269  OUT_WD_DEN_Tumour_WD  Other metabolites   8.416341
# 271  OUT_WD_DEN_Tumour_WD  Other metabolites   0.000000
# 272  OUT_WD_DEN_Tumour_WD  Other metabolites   0.144893
# 273  OUT_WD_DEN_Tumour_WD  Other metabolites   0.000000
# 274  OUT_WD_DEN_Tumour_WD  Other metabolites   0.000000
#
#                     Metabolite     other_group
# 2         2-hydroxybutyrate[s]           Small
# 3                   acetate[s]           Small
# 4                       AKG[s]          AKG[s]
# 5                   betaine[s]      betaine[s]
# 6               cholesterol[s]  cholesterol[s]
# ..                         ...             ...
# 269              riboflavin[s]   riboflavin[s]
# 271                 sulfate[s]           Small
# 272                    urea[s]           Small
# 273  cholesterol-ester pool[l]           Small
# 274                 biomass[s]           Small
#
# [230 rows x 5 columns]

# %%
others = FINAL[FINAL['Group'] == 'Other metabolites']
for index,row in others.iterrows():
    if row['Cmoles'] <= 1:
        others.at[index,'other_group'] = 'Small'
    else:
        others.at[index,'other_group'] = row['Metabolite']
fig = px.bar(others,
             x = 'Model',
             y = 'Cmoles',
             color= 'other_group',
             color_discrete_sequence = plotly.colors.qualitative.Light24_r,
             template = 'none')
fig.update_layout(autosize = False,
                  width = 500,
                  height = 450,
                  xaxis_title='',
                  yaxis_title='Carbon flux (mmol/mouse/day)',
                  margin=dict(l=50,
                              r=20,
                              b=20,
                              t=20,
                              pad=4))
fig = setPlotFont(fig)
fig.update_layout(legend_traceorder="reversed")
fig.update_xaxes(showticklabels=False)
fig.update_xaxes(tickangle=90)
#fig.write_image('../v8/Figures/Figure3/Suppl/FigureS3B_2.pdf')
fig.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="7f86c915-38a3-45f6-83bc-dcd1a8240cfd" class="plotly-graph-div" style="height:450px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f86c915-38a3-45f6-83bc-dcd1a8240cfd")) {                    Plotly.newPlot(                        "7f86c915-38a3-45f6-83bc-dcd1a8240cfd",                        [{"alignmentgroup":"True","hovertemplate":"other_group=Small<br>Model=%{x}<br>Cmoles=%{y}<extra></extra>","legendgroup":"Small","marker":{"color":"#E48F72","pattern":{"shape":""}},"name":"Small","offsetgroup":"Small","orientation":"v","showlegend":true,"textposition":"auto","x":["OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericCD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_genericWD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_CD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_nonDEN_Liver_WD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_Liver_CD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_AdjLiver_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_CD_DEN_Tumour_WD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_CD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_nonDEN_Liver_WD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_Liver_CD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_AdjLiver_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_Tumour_WD","OUT_WD_DEN_ ...
