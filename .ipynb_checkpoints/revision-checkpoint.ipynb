# %%
import pandas as pd
import mygene
import numpy as np
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (5.0.0)/charset_normalizer (2.0.8) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
MMRN_rxns = pd.read_excel('data/models/xlsx/MMRN.xlsx',sheet_name='RXNS',index_col='ID')
MMRN_mets = pd.read_excel('data/models/xlsx/MMRN.xlsx',sheet_name='METS',index_col='ID')

#Hep_rxns = pd.read_excel('data/models/xlsx/genericLiverWD.xlsx',sheet_name='RXNS',index_col='ID')
#Hep_mets = pd.read_excel('data/models/xlsx/genericLiverWD.xlsx',sheet_name='METS',index_col='ID')

#HMR_rxns = pd.read_excel('data/models/HMRdatabase3_00.xlsx',sheet_name='RXNS',index_col='ID')
#HMR_mets = pd.read_excel('data/models/HMRdatabase3_00.xlsx',sheet_name='METS',index_col='METID')

#Recon_rxns = pd.read_excel('data/models/Recon3D_model.xlsx',sheet_name='RXNS',index_col='ID')
#Recon_mets = pd.read_excel('data/models/Recon3D_model.xlsx',sheet_name='METS',index_col='ID')

rxn_map = pd.read_csv('../../../../Integration/scripts/Human-GEM/model/reactions.tsv',sep='\t',index_col='rxns')
met_map = pd.read_csv('../../../../Integration/scripts/Human-GEM/model/metabolites.tsv',sep='\t',index_col='mets')

Human1_rxns = pd.read_excel('../../../../Integration/scripts/Human-GEM/model/Human-GEM.xlsx',
                            sheet_name='RXNS',index_col='ID')

Human1_mets = pd.read_excel('../../../../Integration/scripts/Human-GEM/model/Human-GEM.xlsx',
                            sheet_name='METS',index_col='REPLACEMENT ID')

# %%
Human1_rxns.head()
# Out:
#            # NAME                                           EQUATION  \
# ID
# MAR03905 NaN  NaN  ethanol[c] + NAD+[c] => acetaldehyde[c] + H+[c...
# MAR03907 NaN  NaN  ethanol[c] + NADP+[c] => acetaldehyde[c] + H+[...
# MAR04097 NaN  NaN  acetate[c] + ATP[c] + CoA[c] => acetyl-CoA[c] ...
# MAR04099 NaN  NaN  acetate[m] + ATP[m] + CoA[m] => acetyl-CoA[m] ...
# MAR04108 NaN  NaN  acetyl adenylate[c] + CoA[c] => acetyl-CoA[c] ...
#
#                  EC-NUMBER                                   GENE ASSOCIATION  \
# ID
# MAR03905  1.1.1.1;1.1.1.71  ENSG00000147576 or ENSG00000172955 or ENSG0000...
# MAR03907           1.1.1.2                                    ENSG00000117448
# MAR04097           6.2.1.1                                    ENSG00000131069
# MAR04099           6.2.1.1                 ENSG00000111058 or ENSG00000154930
# MAR04108           6.2.1.1                                    ENSG00000131069
#
#           LOWER BOUND  UPPER BOUND  OBJECTIVE  COMPARTMENT  \
# ID
# MAR03905          NaN          NaN        NaN          NaN
# MAR03907          NaN          NaN        NaN          NaN
# MAR04097          NaN          NaN        NaN          NaN
# MAR04099          NaN          NaN        NaN          NaN
# MAR04108          NaN          NaN        NaN          NaN
#
#                                                      MIRIAM  \
# ID
# MAR03905  kegg.reaction/R00754;bigg.reaction/ALCD2x;vmhr...
# MAR03907  kegg.reaction/R00746;bigg.reaction/ALCD2y;vmhr...
# MAR04097  kegg.reaction/R00235;bigg.reaction/ACS;vmhreac...
# MAR04099  kegg.reaction/R00235;bigg.reaction/ACSm;vmhrea...
# MAR04108  kegg.reaction/R00236;vmhreaction/r0068;metanet...
#
#                              SUBSYSTEM  REPLACEMENT ID NOTE  \
# ID
# MAR03905  Glycolysis / Gluconeogenesis             NaN  NaN
# MAR03907  Glycolysis / Gluconeogenesis             NaN  NaN
# MAR04097  Glycolysis / Gluconeogenesis             NaN  NaN
# MAR04099  Glycolysis / Gluconeogenesis             NaN  NaN
# MAR04108  Glycolysis / Gluconeogenesis             NaN  NaN
#
#                                                   REFERENCE  CONFIDENCE SCORE
# ID
# MAR03905  PMID:10868354;PMID:12491384;PMID:12818203;PMID...                 0
# MAR03907                                                NaN                 0
# MAR04097  PMID:10843999;PMID:11150295;PMID:2884217;PMID:...                 0
# MAR04099  PMID:10843999;PMID:11150295;PMID:2884217;PMID:...                 0
# MAR04108  PMID:10843999;PMID:14086739;PMID:238571;PMID:2...                 0

# %% [markdown]
# # REACTIONS

# %%
MMRN_rxns = pd.read_excel('data/models/xlsx/MMRN.xlsx',sheet_name='RXNS',index_col='ID')
Human1_rxns = pd.read_excel('../../../../Integration/scripts/Human-GEM/model/Human-GEM.xlsx',
                            sheet_name='RXNS',index_col='ID')
rxn_map = pd.read_csv('../../../../Integration/scripts/Human-GEM/model/reactions.tsv',sep='\t',index_col='rxns')

# %%
toadd = ['rxnKEGGID','rxnMetaNetXID','rxnREACTOMEID','rxnRheaID','rxnRheaMasterID','rxnBiGGID']
done = []
for search in ['rxnRetired','rxnRecon3DID','rxnHMR2ID']:
    print(search)
    if search == 'rxnBiGGID':
        rxn_map2 = rxn_map
        rxn_map2['BiGGID'] = rxn_map2['rxnBiGGID']
        rxn_map2 = rxn_map2.set_index('BiGGID')
    else:
        rxn_map2 = rxn_map.set_index(search)
        rxn_map2 = rxn_map2.astype('str')
    rxn_map2 = rxn_map2.drop_duplicates()
    for index,row in MMRN_rxns.iterrows():
        if index in list(rxn_map2.index) and index not in done:
            for col in toadd:
                val = str(rxn_map2.at[index,col])
                #val = val.replace(' ','')
                MMRN_rxns.at[index,col] = str(val)
            done.append(index)
# Out:
# rxnRetired
# rxnRecon3DID
# rxnHMR2ID

# %%
for index,row in MMRN_rxns.iterrows():
    if 'RHEA' in str(row['rxnRheaID']):
        rhea = str(row['rxnRheaID']).replace('RHEA:','') + '; ' +str(row['rxnRheaMasterID']).replace('RHEA:','')
        MMRN_rxns.at[index,'rxnRheaFinal'] = rhea

# %%
for index,row in MMRN_rxns.iterrows():
    miriam = str(row['MIRIAM'])
    parts = miriam.split(';')
    for part in parts:
        if 'SBO' in part:
            MMRN_rxns.at[index,'rxnSBOTerms'] = part.replace('sbo/','')

# %%
MMRN_rxns['EC-NUMBER'] = MMRN_rxns['EC-NUMBER'].str.replace('EC:','')
MMRN_rxns['EC-NUMBER'] = MMRN_rxns['EC-NUMBER'].str.replace(',',';')
MMRN_rxns['EC-NUMBER'] = MMRN_rxns['EC-NUMBER'].str.replace(' ',';')
MMRN_rxns['EC-NUMBER'] = MMRN_rxns['EC-NUMBER'].str.replace('.-','')
MMRN_rxns['EC-NUMBER'] = MMRN_rxns['EC-NUMBER'].str.replace(';or','')
for index,row in MMRN_rxns.iterrows():
    if 'TCDB' in str(row['EC-NUMBER']):
        MMRN_rxns.at[index,'EC-NUMBER'] = ''
# Out:
# /var/folders/zc/h_66z5bx601_njjc__92xndnxk18rv/T/ipykernel_97407/2896705547.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   MMRN_rxns['EC-NUMBER'] = MMRN_rxns['EC-NUMBER'].str.replace('.-','')

# %%
MMRN_rxns['NOTE'] = MMRN_rxns['NOTE'].str.replace('PROTEIN_CLASS: ','')
MMRN_rxns['NOTE'] = MMRN_rxns['NOTE'].str.replace('EC:','')
MMRN_rxns['NOTE'] = MMRN_rxns['NOTE'].str.replace('.-','')
for index,row in MMRN_rxns.iterrows():
    if 'TCDB' in str(row['NOTE']):
        MMRN_rxns.at[index,'NOTE'] = ''
    if 'Included' in str(row['NOTE']):
        MMRN_rxns.at[index,'NOTE'] = ''
# Out:
# /var/folders/zc/h_66z5bx601_njjc__92xndnxk18rv/T/ipykernel_97407/2504204149.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   MMRN_rxns['NOTE'] = MMRN_rxns['NOTE'].str.replace('.-','')

# %%
for item in list(set(MMRN_rxns['NOTE'])):
    print(item)
# Out:
# 2.7.1.158
# 2.1.1.67
# 1.3.8.1;1.3.99.12
# 2.3.1.61
# 2.7.1.48
# 4.4.1.16
# 2.5.1.91
# 2.4.1
# 2.3.1.37
# 2.7.9.3
# 4.1.2.5
# 1.1.1.179
# 2.8.3.5
# 2.7.7.43
# 4.2.3.134
# 1.13.11.71
# 4.3.1.17;4.3.1.19
# 3.6.1.12
# 3.5.1.28
# 2.4.1.155
# 2.6.1.82
# 2.5.1.16
# 1.1.1.1
# 2.1.1.13
# 1.3.8.5
# 2.1.3.85;1.3.1.39
# 3.4.21.35
# 4.2.1.2
# 1.3.1.22
# 1.14.11.16
# 2.4.1.212
# 2.7.4.24
# 1.2.1.47
# 1.2.1.32
# 2.1.1.214;2.1.1.215;2.1.1.216
# 3.1.3.7
# 2.5.1.1;2.5.1.10;2.5.1.29
# 2.4.99.10
# 1.14.13.99
# 2.7.4.2
# 1.2.1.5
# 4.99.1.1
# 2.4.2.15;2.4.2.1
# 3.5.4.13
# 2.5.1.18
# 6.3.5.4
# 1.2.4.4
# 1.1.1.184;1.1.1.232
# 1.4.3.4;1.4.3.6;1.4.3.21;1.4.3.22
# 1.1.1.62;1.1.1.64
# 1.1.1.41
# 5.4.2.2;5.4.2.7
# 3.6.1.5
# 2.1.1.49;2.1.1.6
# 6.2.1.5
# 2.1.1.9
# 6.1.1.5
# 2.4.1.259
# 2.3.1.137
# 3.5.1.2;3.5.1.38
# 2.3.1.48
# 2.7.7.9
# 2.7.1.134
# 2.4.1.18
# 6.1.1.17
# 3.1.6.14
# 2.3.1.26
# 2.3.1.12
# 1.3.99.3
# 2.1.1.28
# 2.7.3.2
# 2.7.1.17
# 1.1.1.59
# 2.4.1.88
# 4.1.1.94
# 3.6.1.5;3.6.1.6
# 2.4.99.3
# 3.1.6.4;3.2.1.18;3.2.1.23;3.4.16.5
# 2.7.1.32
# 3.1.4.37
# 1.1.1.141
# 5.3.1.1
# 4.4.1.20
# 1.1.1.27
# 2.7.1.1;2.7.1.2
# 1.8.1.6
# 2.7.1.20;2.7.1.74
# 3.1
# 3.10.1.1
# 6.3.4.2
# 1.14.15.5
# 1.1.1.30
# 3.1.4.17;3.1.4.35
# 1.2.1.12
# 2.7.9.2
# 3.1.4.44
# 4.2.1.17;1.1.1.35;1.1.1.211;1.3.8.7;1.3.8.8;1.3.8.9;2.3.1.16
# 6.1.1.2
# 2.3.3.1;2.3.3.3
# 1.1.1.1;1.1.1.105
# 5.1.3.19;2.8.2
# 3.4.15
# 1.1.1.300
# 2.7.1.40
# 2.7.7.1
# 5.1.99.1
# 4.2.1.78
# 2.4.1.101
# 3.6.3.8
# 3.6.1.23
# 3.1.2.27;2.3.1.65
# 1.1.1.21
# 1.8.3.1
# 3.1.1.53
# 1.14.13.13
# 3.6.1.39;3.6.1.5
# 6.4.1.2
# 6.3.4.9;6.3.4.10;6.3.4.11;6.3.4.15
# 1.2.1.8
# 3.1.3.36
# 1.4.3.5
# 3.5.1.24
# 1.1.1.209;1.1.1.213;1.1.1.50
# 5.1.3.17
# 3.2.1.46
# 2.1.3.3
# 3.2.1.14
# 2.8.1
# 2.7.1.149
# 4.2.1.55
# 2.3.2.13
# 3.1.3.18
# 3.5.3.4
# 3.1.1.7;3.1.1.8
# 2.7.1.31
# 4.1.1.32
# 6.1.1.14
# 3.2.1.21
# 1.6.5.2
# 3.1.2.2
# 1.4.3.10;1.4.3.6
# 2.3.1.16
# 6.3.5.2
# 3.5.4.16
# 2.5.1.21
# 4.1.1.33
# 2.4.99.6
# 2.5.1.22
# 3.2.1.10
# 2.3.1.5
# 6.3.5.5
# 3.6.1.19
# 6.1.1.1
# 3.4.21.59
# 4.4.1.1
# 3.2.1.52
# 1.14.99.38
# 1.2.4.2
# 2.7.1.74
# 1.14.19.1
# 4.1.1.19
# 2.1.1.98
# 2.4.2.1
# 3.2.2.6
# 1.14.13.72
# 2.7.11.1
# 2.4.1.66
# 1.1.1.330
# 1.1.1.170
# 6.1.1.21
# 1.1.1.271
# 1.1.1.35;1.1.1.211
# 3.6.1.22
# 2.3.1.85;1.3.1.39
# 1.1.99.1
# 2.1.1.64
# 3.7.1.3
# 1.14.13.32
# 1.3.5.1
# 1.1.4.1
# 1.3.8.7
# 4.1.1.35
# 3.1.2.27
# 2.4.1.256
# 3.1.2.15;3.4.19.12
# 1.5.1.20
# 1.3.1.3
# 2.3.1.21
# 2.4.2.8
# 3.5.1.25
# 3.2.1.1
# 2.7.7.2
# 3.1.3.57
# 1.14.15.6
# 3.6.1.13;3.6.1.53
# 3.6.1.6
# 6.1.1.10
# 2.8.2.23;2.8.2.30
# 2.7.1.3
# 2.7.1.11
# 1.13.11.52
# 4.1.1
# 2.7.1.59
# 5.4.2.7
# 3.1.1.47
# 4.4.1.1;4.4.1.8
# 2.1.1.33
# 2.7.6.1
# 2.4.1.11
# 6.3.4.5
# 1.3.8.7;1.3.8.8;1.3.8.9
# 1.11.1.7
# 2.3.2.2
# 1.3.1.93
# 4.1.1.4
# 2.7.7.15
# 2.7.1.173
# 2.7.1.6
# 2.7.8.1
# 2.7.7.1;2.7.7.18
# 1.1.1.22
# 2.4.1.149;2.4.1.163
# 1.1.99.13
# 1.1.1.79;1.1.1.81
# 2.4.99.4
# 1.3.1.3;1.3.99.6
# 1.14.13.100
# 3.1.4.2
# 2.7.7.8
# 1.6.5.3
# 6.1.1.16
# 1.6.2.2
# 1.13.11
# 4.2.1.1
# 3.1.3.25
# 2.7.1.52
# 2.1.1.49
# 1.1.1.153
# 2.4.1.261
# 2.1.2.10
# 1.6.5.5
# 3.1.4.14
# 6.3.4.4
# 1.5.8.4
# 1.11.1.7;1.11.1.8;1.11.2.2
# 5.4.4
# 2.4.2.8;2.4.2.22
# 2.4.2.9
# 3.1.3.56
# 1.17.99.3
# 6.3.2.17
# 4.1.1.9
# 1.1.1.35;1.3.3.6;2.3.1.154;2.3.1.16;3.1.2.2;4.2.1.17;5.1.99.4;6.2.1
# 1.5.1.6
# 3.5.1.1;3.5.1.38
# 1.4.3.6;1.4.3.21;1.4.3.22
# 2.7.7.4
# 2.8.1.2
# 2.3.1.168
# 1.8.1.9
# 2.7.11.19
# 3.5.1.42
# 2.6.1.15;2.6.1.64
# 4.2.3.2
# 2.7.1.151
# 3.1.3.75
# 2.4.2.12
# 6.3.2.19
# 6.1.1.20
# 1.2.1.29
# 2.4.1.23
# 2.1.1.62
# 1.14.17.3
# 2.1.3.2
# 1.5.1.38
# 1.1.1.146
# 2.7.11.18
# 4.1.1.17
# 3.5.99.6
# 1.14.13.98
# 2.1.2.2
# 3.6.1.19;3.6.1.8
# 3.5.2.3
# 3.3.2.9;3.3.2.10
# 2.4.99.20
# 6.3.2.4
# 6.1.1.22
# 6.1.1.3
# 3.5.3.6
# 2.6.1.1
# 2.3.1.85;2.3.1.86;1.1.1.100
# 1.1.1.15
# 4.1.1.21
# 1.14.99.9
# 3.6.3.10
# 2.8.2
# 5.1.3.2
# 6.3.4.1
# 1.16.1.8
# 6.3.5.3
# 2.8.2.14
# 2.4.1.147
# 1.13.11.33
# 2.5.1.61
# 2.3.1.85;4.2.1.59
# 3.2.1.113
# 2.4.1.143
# 3.5.1.3
# 2.4.2.10
# 1.4.3.22
# 2.3.1.85;2.3.1.179
# 3.1.1.3
# 1.6.1.1;1.6.1.2
# 1.1.1
# Included by getModelFromHomology
# 4.3.1.7
# 2.8.2.2
# 5.3.1.23
# 2.7.7.30
# 5.3.1.25
# 4.1.2.13
# 1.13.11.12;1.13.11.33
# 3.1.4.39
# 3.1.2.17;1.2.1.18
# 1.3.1.24
# 2.7.6.2
# 1.14.13.15
# 4.1.1.37
# 3.1.1.29
# 2.4.99.8
# 2.7.7.14
# 3.1.3.43
# 6.3.2.3
# 2.6.1
# 5.3.3.8
# 2.4.1.223;2.4.1.224;2.4.1.225
# 2.1.1.6
# 3.1.2.2;3.1.2.22
# 3.5.1.92
# 3.5.4.12
# 2.4.99
# 2.4.1.68
# 2.7.1.39
# 1.3.3.4
# 4.2.1.22
# 1.14.11.18
# 3.5.2.9
# 2.3.1.50
# 3.4.13.18;3.4.13.20
# 1.14.13.95
# 2.7.1.1;2.7.1.2;2.7.1.147
# 3.2.1.22
# 2.7.11.14
# 2.3.1.154
# 5.3.4.1
# 1.5.3.13;1.5.3.16
# 3.4.16.5;3.2.1.18;3.2.1.23
# 1.14
# 1.1.1.102
# 6.3.4.16
# 6.2.1.1;6.2.1.17
# 1.1.1.239
# 2.8.2.23
# 3.6.1.29
# 3.6.1.13
# 2.1.1.114
# 1.2.1.25
# 1.14.14.1
# 3.1.3.67
# 3.3.2.6;3.4.11.6
# 2.4.99.9
# 2.7.1.140
# 3.6.1.5;3.6.1.6;3.6.1.42
# 1.8.1.4;2.1.2.10
# 2.3.1
# 6.1.1.19
# 4.1
# 1.13.11.34
# 1.1.1.10
# 1.1.1.270
# 1.1.99.2
# 2.6.1.1;2.6.1.7
# 2.4.1.265
# 1.15.1.1
# 3.4.24.16
# 1.3.3.3
# 3.2.1.50
# 1.17.4.1
# 3.1.3.16
# 3.1.3.53
# 1.1.3.15
# 2.4.1.69
# 4.3.1.3
# 6.1.1.6
# 3.5.1.52
# 3.6.1.9;3.6.1.18
# 4.2.1.107
# 3.5.1.89
# 3.1.4.17
# 2.4.2.28
# 5.3.99.2
# 2.4.1.149
# 3.1.3.4
# 2.6.1.52
# 3.1.3.74
# 1.2.1.24
# 2.1.1.1
# 5.3.3.12
# 1.8.1.3
# 4.2.3.12
# 2.3.1.67
# 2.1.1.4
# 3.1.4.38
# 2.3.1.4
# 2.7.1.127
# 3.2.1.35;3.2.1.52
# 6.3.2.11
# 1.3.3.6
# 1.6.3.1;1.11.1
# 5.1.3.14
# 2.3.1.65
# 2.1.1.20
# 4.1.1.50
# 3.6.1.1
# 1
# 3.1.3.33
# 1.1.1.8
# 5.3.1.6
# 4.2.1.46
# 4.2.1.47
# 4.2.1
# 4.1.2.27
# 6.3.3.2
# 2.3.1.88
# 2.4.1.62
# 1.14.13.70
# 2.3.1.97
# 5.3.99.3
# 4.1.99.18
# 2.6.1.5
# 4.3.2.2
# 1.7.3.3
# 1.7.1.7
# 2.3.1.78
# 3.5.2.7
# 2.7.1.33
# 4.1.1.22;4.1.1.28
# 2.4.1.131
# 1.2.1.88
# 1.8.3.5;1.8.3.6
# 3.1.4.35
# 1.10.2.2
# 1.1.1.145
# 5.4.2.2;5.4.2.5;5.4.2.6;5.2.2.2
# 2.4.1.87
# 3.5.3.18
# 2.3.2.8
# 3.5.4.9;6.3.4.3
# 3.5.2.5
# 3.1.2.4
# 2.4.2.30
# 6.2.1.3
# 4.2.1.70
# 3.6.1.22;3.6.1.9
# 6.2.1.2
# 3.1.3.62
# 1.13.11.5
# 2.7.1.28
# 1.5.1.8
# 3.5.4.3
# 6.3.2.25
# 2.7.4.14;2.7.4.4
# 3.5.
# 4.2.1.17
# 4.2.1.75
# 1.1.5.3
# 3.4.19.5
# 1.14.18.1
# 1.13.99.1
# 3.6.1.43
# 1.14.18.2
# 2.1.1
# 3.5.4.17;3.5.4.6
# 2.4.2.7
# 2.4.1.175;2.4.1.226
# 3.6.3.9
# 3.6.1.28
# 2.7.1.36
# Spontaneous
# 2.7.1.26
# 1.1.1.11
# 2.4.1.141
# 2.7.8.2
# 2.8.2.17
# 2.4.1.92
# 1.14.13.67
# 2.7.1.15
# 1.17.3.2
# 3.1.2.12
# 2.7.1.159
# 2.5.1.39
# 1.14.21.6
# 2.1.1.103
# 2.5.1.46
# 1.14.13.132
# 6.2.1.4
# 1.14.15.4
# 2.7.1.14
# 3.1.3.2
# 2.3.1.42
# 6.3.5.1
# 6.5.1.4
# 1.5.3.1;1.5.3.7
# 2.7.1.113
# 1.1.1.105
# 2.7.1.21
# 2.1.1.43
# 2.4.1.150
# 3.4.16.5;3.2.1.35;3.1.6.4;3.2.1.23
# 4.1.1.36
# 2.3.1.85;2.3.1.41;2.3.1.179
# 3.4.13.19
# 1.14.13.80
# 3.4.14.9
# 2.7.11.15
# 2.7.11.2
# 1.3.5.2;1.3.1.14
# 2.4.99.7
# 2.7.4.14;2.7.4.25
# 1.1.1.37
# 3.1.1.2
# 2.4.1.37
# 2.3.1.9
# 6.3.3.1
# 2.7.1.154
# 1.5.1.9
# 4.2.1.77
# 4.1.3.16
# 2.7.1.24
# 1.14.19.3
# 2.4.1.102
# 2.4.1.226
# 3.6.1.25
# 6.2.1.12
# 2.1.1.2
# 2.7.1.33;2.7.1.34
# 2.4.99.18
# 3.1.2.6
# 1.13.11.31
# 1.14.19
# 1.11.1.7;1.2.4.4;1.8.1.4
# 4.1.1.15

# %%
counter = 0
MMRN_index = []
MMRN_rxns['RetiredID'] = MMRN_rxns.index
for i in MMRN_rxns.index:
    counter += 1
    string_counter = str(counter)
    string_counter = string_counter.zfill(5)
    MMRN_index.append(str('MMRNR'+string_counter))
MMRN_rxns['MMRN_index'] = MMRN_index
MMRN_rxns = MMRN_rxns.set_index('MMRN_index')

# %%
MMRN_rxns.fillna('', inplace=True)
MMRN_rxns = MMRN_rxns.replace(np.nan, '', regex=True)

# %%
MMRN_rxns
# Out:
#            #                   NAME  \
# MMRN_index
# MMRNR00001               R_HMR_0154
# MMRNR00002               R_HMR_0189
# MMRNR00003               R_HMR_0193
# MMRNR00004               R_HMR_0197
# MMRNR00005               R_HMR_0201
# ...        ..                   ...
# MMRNR10777        MMRN_Protein_pool
# MMRNR10778     MMRN_Nucleotide_pool
# MMRNR10779            MMRN_glycogen
# MMRNR10780             MMRN_Biomass
# MMRNR10781
#
#                                                      EQUATION EC-NUMBER  \
# MMRN_index
# MMRNR00001  H2O[c] + propanoyl-CoA[c] => CoA[c] + propanoa...
# MMRNR00002  H2O[c] + lauroyl-CoA[c] => CoA[c] + lauric aci...
# MMRNR00003  H2O[c] + tridecanoyl-CoA[c] => CoA[c] + tridec...
# MMRNR00004  H2O[c] + myristoyl-CoA[c] => CoA[c] + myristic...
# MMRNR00005  (9E)-tetradecenoyl-CoA[c] + H2O[c] => (9E)-tet...
# ...                                                       ...       ...
# MMRNR10777  0.0804189944096 alanine[c] + 0.000628258574808...
# MMRNR10778  0.197442441921 DNA[n] + 0.802557558079 RNA[c] ...
# MMRNR10779            glycogen[c] => glycogen_pool_biomass[c]
# MMRNR10780  0.001 cofactors and vitamins[c] + 0.26551 glyc...
# MMRNR10781                           biomass[c] => biomass[s]
#
#                                              GENE ASSOCIATION LOWER BOUND  \
# MMRN_index
# MMRNR00001  ENSMUSG00000021226 or ENSMUSG00000021228 or EN...
# MMRNR00002  ENSMUSG00000021226 or ENSMUSG00000021228 or EN...
# MMRNR00003  ENSMUSG00000021226 or ENSMUSG00000021228 or EN...
# MMRNR00004  ENSMUSG00000021226 or ENSMUSG00000021228 or EN...
# MMRNR00005  ENSMUSG00000021226 or ENSMUSG00000021228 or EN...
# ...                                                       ...         ...
# MMRNR10777
# MMRNR10778
# MMRNR10779
# MMRNR10780
# MMRNR10781
#
#            UPPER BOUND OBJECTIVE COMPARTMENT MIRIAM  ... REFERENCE  \
# MMRN_index                                           ...
# MMRNR00001                                           ...
# MMRNR00002                                           ...
# MMRNR00003                                           ...
# MMRNR00004                                           ...
# MMRNR00005                                           ...
# ...                ...       ...         ...    ...  ...       ...
# MMRNR10777                                           ...
# MMRNR10778                                           ...
# MMRNR10779                                           ...
# MMRNR10780                                           ...
# MMRNR10781                                           ...
#
#            CONFIDENCE SCORE rxnKEGGID rxnMetaNetXID rxnREACTOMEID   rxnRheaID  \
# MMRN_index
# MMRNR00001              0.0       nan           nan           nan  RHEA:40104
# MMRNR00002              0.0       nan           nan           nan         nan
# MMRNR00003              0.0       nan           nan           nan         nan
# MMRNR00004              0.0       nan           nan           nan         nan
# MMRNR00005              0.0       nan           nan           nan         nan
# ...                     ...       ...           ...           ...         ...
# MMRNR10777
# MMRNR10778
# MMRNR10779
# MMRNR10780
# MMRNR10781
#
#            rxnRheaMasterID rxnBiGGID  rxnRheaFinal             RetiredID
# MMRN_index
# MMRNR00001      RHEA:40103       nan  40104, 40103              HMR_0154
# MMRNR00002             nan       nan                            HMR_0189
# MMRNR00003             nan       nan                            HMR_0193
# MMRNR00004             nan       nan                            HMR_0197
# MMRNR00005             nan       nan                            HMR_0201
# ...                    ...       ...           ...                   ...
# MMRNR10777                                             MMRN_Protein_pool
# MMRNR10778                                          MMRN_Nucleotide_pool
# MMRNR10779                                                 MMRN_glycogen
# MMRNR10780                                                  MMRN_Biomass
# MMRNR10781                                                     HMR_10023
#
# [10781 rows x 23 columns]

# %%
MMRN_rxns.to_csv('data/models/xlsx/MMRN_rxns.csv')

# %% [markdown]
# # METABOLITES

# %%
MMRN_mets = pd.read_excel('data/models/xlsx/MMRN.xlsx',sheet_name='METS',index_col='ID')
met_map = pd.read_csv('../../../../Integration/scripts/Human-GEM/model/metabolites.tsv',sep='\t',index_col='mets')
Human1_mets = pd.read_excel('../../../../Integration/scripts/Human-GEM/model/Human-GEM.xlsx',
                            sheet_name='METS',index_col='REPLACEMENT ID')

# %%
for index,row in MMRN_mets.iterrows():
    MMRN_mets.at[index,'old'] = row['REPLACEMENT ID'].split('[')[0]
    MMRN_mets.at[index,'RetiredID'] = row['REPLACEMENT ID']
    if '/' in str(row['MIRIAM']):
        parts = row['MIRIAM'].split(';')
        for part in parts:
            part = part.split('/')
            if 'CHEBI' in part[0]:
                MMRN_mets.at[index,part[0]] = 'CHEBI:'+part[1]
            else:
                MMRN_mets.at[index,part[0]] = part[1]

# %%
met_map_kegg['mets'] = met_map_kegg.index
met_map_kegg = met_map.reset_index().set_index('metKEGGID')
met_map_kegg = met_map_kegg[~met_map_kegg.index.duplicated(keep='first')]
for index,row in MMRN_mets.iterrows():
    if row['old'] in met_map_kegg.index:
        kegg = MMRN_mets.at[index,'old']
        MMRN_mets.at[index,'kegg.compound'] = kegg
        MMRN_mets.at[index,'hmdb'] = met_map_kegg.at[kegg,'metHMDBID']
        MMRN_mets.at[index,'pubchem.compound'] = met_map_kegg.at[kegg,'metPubChemID']
        MMRN_mets.at[index,'obo.chebi:CHEBI'] = met_map_kegg.at[kegg,'metChEBIID']
        MMRN_mets.at[index,'lipidmaps'] = met_map_kegg.at[kegg,'metLipidMapsID']
        
        human = met_map_kegg.at[kegg,'mets']
        miriam = Human1_mets.at[human,'MIRIAM']
        MMRN_mets.at[index,'MIRIAM'] = miriam

# %%
for index,row in MMRN_mets.iterrows():
    miriam = str(row['MIRIAM'])
    parts = miriam.split(';')
    for part in parts:
        if 'SBO' in part:
            MMRN_mets.at[index,'metSBOTerms'] = part.replace('sbo/','')

# %%
counter = 0
done = {}
for index,row in MMRN_mets.iterrows():
    if row['NAME'] not in done:
        counter += 1
        string_counter = str(counter)
        string_counter = string_counter.zfill(4)
        new_id = 'MMRNM' + str(string_counter) + row['COMPARTMENT']
        MMRN_mets.at[index,'REPLACEMENT ID'] = new_id
        done[row['NAME']] = 'MMRNM' + str(string_counter)
    else:
        new_id = done[row['NAME']] + row['COMPARTMENT']
        MMRN_mets.at[index,'REPLACEMENT ID'] = new_id

# %%
MMRN_mets.to_csv('data/models/xlsx/MMRN_mets.csv')

# %% [markdown]
# # GENES

# %%
MMRN_gene = pd.read_excel('data/models/xlsx/MMRN.xlsx',sheet_name='GENES',index_col='NAME')

# %%
MMRN_gene.head(1)
# Out:
#                      #  MIRIAM  SHORT NAME  COMPARTMENT
# NAME
# ENSMUSG00000000088 NaN     NaN         NaN          NaN

# %%
mg = mygene.MyGeneInfo()
ginfo = mg.querymany(list(MMRN_gene.index), scopes='ensembl.gene',fields='all')
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-3462...done.
# Finished.
# 57 input query terms found no hit:
# 	['ENSMUSG00000024952', 'ENSMUSG00000039530', 'ENSMUSG00000079834', 'ENSMUSG00000096994', 'ENSMUSG000
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
all_miriams = {}
for gene in ginfo:
    query = gene['query']
    try:
        ensembl = gene['ensembl']
        if isinstance(ensembl, list):
            ensembl_gene = []
            ensembl_trans = []
            ensembl_protein = []
            for i in ensembl:
                ensembl_gene.append(i['gene'])
                if isinstance(i['transcript'], list):
                    for j in i['transcript']:
                        ensembl_trans.append(j)
                else:
                    ensembl_trans.append(i['transcript'])
                if isinstance(i['protein'], list):
                    for j in i['protein']:
                        ensembl_protein.append(j)
                else:
                    ensembl_protein.append(i['protein'])
        else:
            ensembl_gene = ensembl['gene']
            ensembl_trans = ensembl['transcript']
            ensembl_protein = ensembl['protein']
        if isinstance(ensembl_gene, list):
            ensembl_gene = str('; '.join(ensembl_gene))
        if isinstance(ensembl_trans, list):
            ensembl_trans = str('; '.join(ensembl_trans))
        if isinstance(ensembl_protein, list):
            ensembl_protein = str('; '.join(ensembl_protein))
            
        MMRN_gene.at[query,'ensembl_gene'] = ensembl_gene
        MMRN_gene.at[query,'ensembl_transcript'] = ensembl_trans
# 50873
# 68262
# 20519
# 20517
# 110460
# 12648
# 23984
# 268930
# 74011
# 27226
# 94185
# 17850
# 19743
# 224805
# 63959
# 20888
# 63993
# 80905
# 56050
# 224826
# 106504
# 18712
# 74157
# 109801
# 11307
# 224674
# 78330
# 12411
# 64898
# 170716
# 71685
# 22436
# 50850
# 210148
# 75292
# 12211
# 19106
# 224938
# 70536
# 17158
# 13078
# 72900
# 11984
# 18607
# 27410
# 20532
# 13177
# 18701
# 14651
# 100503895
# 56520
# 69191
# 19252
# 328845
# 271424
# 56409
# 109791
# 67993
# 67328
# 26410
# 225028
# 20463
# 67470
# 106957
# 19877
# 64385
# 77805
# 225164
# 56515
# 19763
# 14977
# 20522
# 13079
# 170459
# 13872
# 26405
# 13001
# 66237
# 66878
# 11829
# 18145
# 69192
# 15183
# 24010
# 240215
# 107045
# 72930
# 22240
# 15488
# 114663
# 12683
# 16948
# 27411
# 107029
# 225724
# 50771
# 225600
# 93687
# 70223
# 14151
# 83814
# 20496
# 225579
# 67988
# 12322
# 107272
# 66054
# 18399
# 66514
# 60527
# 56473
# 54391
# 225997
# 28000
# 65221
# 26358
# 70999
# 67717
# 76630
# 14102
# 16889
# 56248
# 59028
# 73166
# 107765
# 74126
# 74493
# 109113
# 104174
# 18969
# 12660
# 110355
# 71670
# 18719
# 67689
# 54447
# 13340
# 18563
# 17330
# 23972
# 12894
# 13041
# 81601
# 20510
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zc/h_66z5bx601_njjc__92xndnxk18rv/T/ipykernel_68754/2750535238.py in <module>
#       1 for gene in ginfo:
#       2     query = gene['query']
# ----> 3     uniprot = gene['entrezgene']
#       4     print(uniprot)
#
# KeyError: 'entrezgene'

# %%
ginfo[0]
# Out:
# {'query': 'ENSMUSG00000000088',
#  'AllianceGenome': '88474',
#  'MGI': 'MGI:88474',
#  '_id': '12858',
#  '_score': 21.357311,
#  'accession': {'genomic': ['AC164548.3', 'CH466522.1', 'NC_000075.7'],
#   'protein': ['AAH34302.1',
#    'BAB31369.1',
#    'CAA34085.1',
#    'EDL25906.1',
#    'NP_031773.2',
#    'P12787.2',
#    'XP_030099894.1',
#    'XP_036010484.1'],
#   'rna': ['AK018723.1',
#    'BC003831.1',
#    'BC034302.1',
#    'BY259203.1',
#    'CO044753.1',
#    'NM_007747.2',
#    'X15963.1',
#    'XM_030244034.2',
#    'XM_036154591.1'],
#   'translation': [{'protein': 'NP_031773.2', 'rna': 'NM_007747.2'},
#    {'protein': 'XP_030099894.1', 'rna': 'XM_030244034.2'},
#    {'protein': 'AAH34302.1', 'rna': 'BC034302.1'},
#    {'protein': 'BAB31369.1', 'rna': 'AK018723.1'},
#    {'protein': 'XP_036010484.1', 'rna': 'XM_036154591.1'},
#    {'protein': 'CAA34085.1', 'rna': 'X15963.1'}]},
#  'alias': ['AA959768', 'CcOX'],
#  'ec': '7.1.1.9',
#  'ensembl': {'gene': 'ENSMUSG00000000088',
#   'protein': 'ENSMUSP00000000090',
#   'transcript': ['ENSMUST00000000090',
#    'ENSMUST00000213678',
#    'ENSMUST00000214154'],
#   'translation': [{'protein': 'ENSMUSP00000000090',
#     'rna': 'ENSMUST00000000090'}],
#   'type_of_gene': 'protein_coding'},
#  'entrezgene': '12858',
#  'exons': [{'cdsend': 57439065,
#    'cdsstart': 57428610,
#    'chr': '9',
#    'position': [[57428514, 57428698],
#     [57436238, 57436355],
#     [57437523, 57437645],
#     [57438951, 57439075],
#     [57439564, 57439709]],
#    'strand': 1,
#    'transcript': 'NM_007747',
#    'txend': 57439709,
#    'txstart': 57428514}],
#  'exons_mm10': [{'cdsend': 57531782,
#    'cdsstart': 57521327,
#    'chr': '9',
#    'position': [[57521231, 57521415],
#     [57528955, 57529072],
#     [57530240, 57530362],
#     [57531668, 57531792],
#     [57532281, 57532426]],
#    'strand': 1,
#    'transcript': 'NM_007747',
#    'txend': 57532426,
#    'txstart': 57521231}],
#  'exons_mm9': [{'cdsend': 57379589,
#    'cdsstart': 57369134,
#    'chr': '9',
#    'position': [[57369038, 57369222],
#     [57376762, 57376879],
#     [57378047, 57378169],
#     [57379475, 57379599],
#     [57380088, 57380233]],
#    'strand': 1,
#    'transcript': 'NM_007747',
#    'txend': 57380233,
#    'txstart': 57369038}],
#  'generif': [{'pubmed': 16291927,
#    'text': 'gene expression of the Cox subunits, Cox5a, 5b, and 6b1 is not required for embryo developmental events up to the blastocyst stage'},
#   {'pubmed': 16303765,
#    'text': 'Protein kinase A-mediated phosphorylation modulates cytochrome c oxidase function and augments hypoxia and myocardial ischemia-related injury'},
#   {'pubmed': 25575679,
#    'text': 'SCN2B could play an important role in the aging-related cognitive deterioration, which is associated with the regulations of COX5A and FGF-2.'}],
#  'genomic_pos': {'chr': '9',
#   'end': 57439709,
#   'ensemblgene': 'ENSMUSG00000000088',
#   'start': 57428557,
#   'strand': 1},
#  'genomic_pos_mm9': {'chr': '9',
#   'end': 57380231,
#   'start': 57369039,
#   'strand': 1},
#  'go': {'BP': {'evidence': 'IBA',
#    'gocategory': 'BP',
#    'id': 'GO:0006123',
#    'pubmed': 21873635,
#    'qualifier': 'involved_in',
#    'term': 'mitochondrial electron transport, cytochrome c to oxygen'},
#   'CC': [{'evidence': 'HDA',
#     'gocategory': 'CC',
#     'id': 'GO:0005739',
#     'pubmed': [14651853, 18614015],
#     'qualifier': 'located_in',
#     'term': 'mitochondrion'},
#    {'evidence': 'IDA',
#     'gocategory': 'CC',
#     'id': 'GO:0005739',
#     'pubmed': [14645204, 19837698, 22792342],
#     'qualifier': 'located_in',
#     'term': 'mitochondrion'},
#    {'evidence': 'HDA',
#     'gocategory': 'CC',
#     'id': 'GO:0005743',
#     'pubmed': 12865426,
#     'qualifier': 'located_in',
#     'term': 'mitochondrial inner membrane'},
#    {'evidence': 'ISO',
#     'gocategory': 'CC',
#     'id': 'GO:0005743',
#     'qualifier': 'located_in',
#     'term': 'mitochondrial inner membrane'},
#    {'evidence': 'IBA',
#     'gocategory': 'CC',
#     'id': 'GO:0005751',
#     'pubmed': 21873635,
#     'qualifier': 'part_of',
#     'term': 'mitochondrial respiratory chain complex IV'},
#    {'evidence': 'IDA',
#     'gocategory': 'CC',
#     'id': 'GO:0005751',
#     'pubmed': 31536960,
#     'qualifier': 'part_of',
#     'term': 'mitochondrial respiratory chain complex IV'},
#    {'evidence': 'ISO',
#     'gocategory': 'CC',
#     'id': 'GO:0005751',
#     'qualifier': 'part_of',
#     'term': 'mitochondrial respiratory chain complex IV'},
#    {'evidence': 'IEA',
#     'gocategory': 'CC',
#     'id': 'GO:0016020',
#     'qualifier': 'located_in',
#     'term': 'membrane'},
#    {'evidence': 'ISO',
#     'gocategory': 'CC',
#     'id': 'GO:0031966',
#     'qualifier': 'located_in',
#     'term': 'mitochondrial membrane'},
#    {'evidence': 'HDA',
#     'gocategory': 'CC',
#     'id': 'GO:0043209',
#     'pubmed': 17634366,
#     'qualifier': 'located_in',
#     'term': 'myelin sheath'}],
#   'MF': [{'category': 'MF',
#     'evidence': 'ISO',
#     'id': 'GO:0004129',
#     'qualifier': 'enables',
#     'term': 'cytochrome-c oxidase activity'},
#    {'category': 'MF',
#     'evidence': 'IPI',
#     'id': 'GO:0005515',
#     'pubmed': 31536960,
#     'qualifier': 'enables',
#     'term': 'protein binding'},
#    {'category': 'MF',
#     'evidence': 'IEA',
#     'id': 'GO:0046872',
#     'qualifier': 'enables',
#     'term': 'metal ion binding'}]},
#  'homologene': {'genes': [[6239, 176707],
#    [7165, 1270770],
#    [7227, 41432],
#    [7955, 554101],
#    [8364, 549803],
#    [9031, 769735],
#    [9544, 692061],
#    [9598, 453750],
#    [9606, 9377],
#    [9615, 478370],
#    [9913, 444878],
#    [10090, 12858],
#    [10116, 252934]],
#   'id': 37905},
#  'interpro': [{'desc': 'Cytochrome c oxidase, subunit Va/VI',
#    'id': 'IPR003204',
#    'short_desc': 'Cyt_c_oxidase_su5A/6'},
#   {'desc': 'Cytochrome c oxidase, subunit Va/VI superfamily',
#    'id': 'IPR036545',
#    'short_desc': 'Cyt_c_oxidase_su5A/6_sf'}],
#  'ipi': 'IPI00120719',
#  'map_location': '9|9 B',
#  'name': 'cytochrome c oxidase subunit 5A',
#  'other_names': ['cytochrome c oxidase polypeptide Va',
#   'cytochrome c oxidase subunit 5A, mitochondrial',
#   'cytochrome c oxidase subunit Va'],
#  'pantherdb': {'MGI': 'MGI:88474',
#   '_license': 'http://pantherdb.org/tou.jsp',
#   'ortholog': [{'RGD': '620607',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 10116,
#     'uniprot_kb': 'P11240'},
#    {'Ensembl': 'ENSGALG00000014121',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 9031,
#     'uniprot_kb': 'E1C043'},
#    {'ZFIN': 'ZDB-GENE-030131-5162',
#     'ortholog_type': 'O',
#     'panther_family': 'PTHR14200',
#     'taxid': 7955,
#     'uniprot_kb': 'A0A0R4IVC8'},
#    {'ZFIN': 'ZDB-GENE-050522-133',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 7955,
#     'uniprot_kb': 'Q4VBU7'},
#    {'WormBase': 'WBGene00012553',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 6239,
#     'uniprot_kb': 'P55954'},
#    {'FlyBase': 'FBgn0019624',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 7227,
#     'uniprot_kb': 'Q94514'},
#    {'SGD': 'S000001093',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 4932,
#     'uniprot_kb': 'P00427'},
#    {'PomBase': 'SPAC1B2.04',
#     'ortholog_type': 'LDO',
#     'panther_family': 'PTHR14200',
#     'taxid': 4896,
#     'uniprot_kb': 'Q9UTF6'}],
#   'uniprot_kb': 'P12787'},
#  'pathway': {'kegg': [{'id': 'mmu00190',
#     'name': 'Oxidative phosphorylation - Mus musculus (mouse)'},
#    {'id': 'mmu04260',
#     'name': 'Cardiac muscle contraction - Mus musculus (mouse)'},
#    {'id': 'mmu04714', 'name': 'Thermogenesis - Mus musculus (mouse)'},
#    {'id': 'mmu04932',
#     'name': 'Non-alcoholic fatty liver disease - Mus musculus (mouse)'},
#    {'id': 'mmu05010', 'name': 'Alzheimer disease - Mus musculus (mouse)'},
#    {'id': 'mmu05012', 'name': 'Parkinson disease - Mus musculus (mouse)'},
#    {'id': 'mmu05014',
#     'name': 'Amyotrophic lateral sclerosis - Mus musculus (mouse)'},
#    {'id': 'mmu05016', 'name': 'Huntington disease - Mus musculus (mouse)'},
#    {'id': 'mmu05020', 'name': 'Prion disease - Mus musculus (mouse)'},
#    {'id': 'mmu05022',
#     'name': 'Pathways of neurodegeneration - multiple diseases - Mus musculus (mouse)'},
#    {'id': 'mmu05208',
#     'name': 'Chemical carcinogenesis - reactive oxygen species - Mus musculus (mouse)'},
#    {'id': 'mmu05415',
#     'name': 'Diabetic cardiomyopathy - Mus musculus (mouse)'}],
#   'mousecyc': {'id': 'PWY-3781',
#    'name': 'aerobic respiration -- electron donor II'},
#   'reactome': [{'id': 'R-MMU-1428517',
#     'name': 'The citric acid (TCA) cycle and respiratory electron transport'},
#    {'id': 'R-MMU-1430728', 'name': 'Metabolism'},
#    {'id': 'R-MMU-163200',
#     'name': 'Respiratory electron transport, ATP synthesis by chemiosmotic coupling, and heat production by uncoupling proteins.'},
#    {'id': 'R-MMU-212436', 'name': 'Generic Transcription Pathway'},
#    {'id': 'R-MMU-2262752', 'name': 'Cellular responses to stress'},
#    {'id': 'R-MMU-3700989', 'name': 'Transcriptional Regulation by TP53'},
#    {'id': 'R-MMU-5628897', 'name': 'TP53 Regulates Metabolic Genes'},
#    {'id': 'R-MMU-611105', 'name': 'Respiratory electron transport'},
#    {'id': 'R-MMU-73857', 'name': 'RNA Polymerase II Transcription'},
#    {'id': 'R-MMU-74160', 'name': 'Gene expression (Transcription)'},
#    {'id': 'R-MMU-8953897', 'name': 'Cellular responses to stimuli'},
#    {'id': 'R-MMU-9707564', 'name': 'Cytoprotection by HMOX1'},
#    {'id': 'R-MMU-9711123', 'name': 'Cellular response to chemical stress'}]},
#  'pdb': ['7O37', '7O3C', '7O3E'],
#  'pfam': 'PF02284',
#  'pir': 'S05495',
#  'reagent': {'GNF_mm+hs-MGC': {'id': 'GNF022539', 'relationship': 'is'},
#   'GNF_mm+hs_RetroCDNA': {'id': 'GNF243093', 'relationship': 'is'}},
#  'refseq': {'genomic': 'NC_000075.7',
#   'protein': ['NP_031773.2', 'XP_030099894.1', 'XP_036010484.1'],
#   'rna': ['NM_007747.2', 'XM_030244034.2', 'XM_036154591.1'],
#   'translation': [{'protein': 'XP_036010484.1', 'rna': 'XM_036154591.1'},
#    {'protein': 'XP_030099894.1', 'rna': 'XM_030244034.2'},
#    {'protein': 'NP_031773.2', 'rna': 'NM_007747.2'}]},
#  'reporter': {'GNF1M': ['gnf1m10850_a_at', 'gnf1m26428_at'],
#   'MG-U74Av2': ['160438_at', '161490_at'],
#   'MTA-1_0': 'TC0900000705.mm.1',
#   'MoEx-1_0': '6989406',
#   'MoGene-1_1': '10585706',
#   'MoGene-2_1': '17517727',
#   'Mouse430_2': ['1415933_a_at', '1448153_at']},
#  'retired': 103611,
#  'symbol': 'Cox5a',
#  'taxid': 10090,
#  'type_of_gene': 'protein-coding',
#  'unigene': 'Mm.273403',
#  'uniprot': {'Swiss-Prot': 'P12787'}}

# %%
# Out:
#     #                NAME  MIRIAM  SHORT NAME  COMPARTMENT
# 0 NaN  ENSMUSG00000000088     NaN         NaN          NaN
# 1 NaN  ENSMUSG00000000131     NaN         NaN          NaN

# %%
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-3462...done.
# Finished.
# 57 input query terms found no hit:
# 	['ENSMUSG00000024952', 'ENSMUSG00000039530', 'ENSMUSG00000079834', 'ENSMUSG00000096994', 'ENSMUSG000
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.

# %%
i = mg.querymany(['ENSMUSG00000000088'], scopes='ensembl.gene',fields='all')
# Out:
# querying 1-1...done.
# Finished.

# %%
all_miriams = {}
for gene in ginfo:
    miriams = []
    query = gene['query']
    try:
        ensembl = gene['ensembl']
        if isinstance(ensembl, list):
            for i in ensembl:
                ensembl_gene = i['gene']
                ensembl_trans = str('ensembl/'.join(list(i['transcript'])))
                miriams.append('ensembl/'+ensembl_gene)
        else:
            ensembl_gene = ensembl['gene']
            ensembl_trans = str('ensembl/'.join(list(i['transcript'])))
            miriams.append('ensembl/'+ensembl_gene)
    except KeyError:
        pass
    print(str(';'.join(miriams)))
# Out:
# ensembl/ENSMUSG00000000088
# ensembl/ENSMUSG00000000131
# ensembl/ENSMUSG00000000154
# ensembl/ENSMUSG00000000168
# ensembl/ENSMUSG00000000171
# ensembl/ENSMUSG00000000214
# ensembl/ENSMUSG00000000253
# ensembl/ENSMUSG00000000276
# ensembl/ENSMUSG00000000301
# ensembl/ENSMUSG00000000308
# ensembl/ENSMUSG00000000320
# ensembl/ENSMUSG00000000326
# ensembl/ENSMUSG00000000339
# ensembl/ENSMUSG00000000340
# ensembl/ENSMUSG00000000399
# ensembl/ENSMUSG00000000411
# ensembl/ENSMUSG00000000420
# ensembl/ENSMUSG00000000439
# ensembl/ENSMUSG00000000441
# ensembl/ENSMUSG00000000530
# ensembl/ENSMUSG00000000532
# ensembl/ENSMUSG00000000563
# ensembl/ENSMUSG00000000594
# ensembl/ENSMUSG00000000628
# ensembl/ENSMUSG00000000673
# ensembl/ENSMUSG00000000708
# ensembl/ENSMUSG00000000787
# ensembl/ENSMUSG00000000792
# ensembl/ENSMUSG00000000804
# ensembl/ENSMUSG00000000805
# ensembl/ENSMUSG00000083079
# ensembl/ENSMUSG00000083138
# ensembl/ENSMUSG00000083282
# ensembl/ENSMUSG00000084346
# ensembl/ENSMUSG00000084927
# ensembl/ENSMUSG00000087141
# ensembl/ENSMUSG00000087408
# ensembl/ENSMUSG00000089634
# ensembl/ENSMUSG00000089675
# ensembl/ENSMUSG00000089678
# ensembl/ENSMUSG00000089704
# ensembl/ENSMUSG00000089774
# ensembl/ENSMUSG00000089789
# ensembl/ENSMUSG00000089872
# ensembl/ENSMUSG00000089917
# ensembl/ENSMUSG00000089943
# ensembl/ENSMUSG00000089960
# ensembl/ENSMUSG00000089992
# ensembl/ENSMUSG00000090035
# ensembl/ENSMUSG00000090083
# ensembl/ENSMUSG00000090112
# ensembl/ENSMUSG00000090115
# ensembl/ENSMUSG00000090124
# ensembl/ENSMUSG00000090145
# ensembl/ENSMUSG00000090150
# ensembl/ENSMUSG00000090165
# ensembl/ENSMUSG00000090171
# ensembl/ENSMUSG00000090175
# ensembl/ENSMUSG00000090266
# ensembl/ENSMUSG00000090290
# ensembl/ENSMUSG00000090700
# ensembl/ENSMUSG00000090817
# ensembl/ENSMUSG00000091043
# ensembl/ENSMUSG00000091212
# ensembl/ENSMUSG00000091387
# ensembl/ENSMUSG00000091415
# ensembl/ENSMUSG00000091586
# ensembl/ENSMUSG00000091813
# ensembl/ENSMUSG00000091867
# ensembl/ENSMUSG00000091896
# ensembl/ENSMUSG00000092008
# ensembl/ENSMUSG00000092300
# ensembl/ENSMUSG00000092305
# ensembl/ENSMUSG00000092471
# ensembl/ENSMUSG00000093806
# ensembl/ENSMUSG00000093930
# ensembl/ENSMUSG00000093931
# ensembl/ENSMUSG00000094559
# ensembl/ENSMUSG00000094806
# ensembl/ENSMUSG00000095143
# ensembl/ENSMUSG00000095388
# ensembl/ENSMUSG00000095463
# ensembl/ENSMUSG00000095576
# ensembl/ENSMUSG00000096145
# ensembl/ENSMUSG00000096569
# ensembl/ENSMUSG00000096764
# ensembl/ENSMUSG00000096770
# ensembl/ENSMUSG00000096852
# ensembl/ENSMUSG00000096914
#
#
#
#
#
#
# ensembl/ENSMUSG00000098488
#
#
# ensembl/ENSMUSG00000099009
#
# ensembl/ENSMUSG00000099974
# ensembl/ENSMUSG00000100241
# ensembl/ENSMUSG00000101959
# ensembl/ENSMUSG00000102758
# ensembl/ENSMUSG00000103766
# ensembl/ENSMUSG00000104445
#
# ensembl/ENSMUSG00000105082
# ensembl/ENSMUSG00000105204
#
# ensembl/ENSMUSG00000106677
#
#
#
#
#
#
#
#
#
#
# ensembl/ENSMUSG00000109324
# ensembl/ENSMUSG00000109511
# ensembl/ENSMUSG00000030653;ensembl/ENSMUSG00000110195
#
#
#
#
#
#
#
# ensembl/ENSMUSG00000111410
#
#
# ensembl/ENSMUSG00000111709
#
#
#
# ensembl/ENSMUSG00000115338
#
#
#
#
#
#
# ensembl/ENSMUSG00000116165
#
# ensembl/ENSMUSG00000116207
#
#
#
#
#
# ensembl/ENSMUSG00000006378;ensembl/ENSMUSG00000116378
#
#
#
#
#
#
# ensembl/ENSMUSG00000116564
#
#
# ensembl/ENSMUSG00000002831
# ensembl/ENSMUSG00000004815
# ensembl/ENSMUSG00000011884
# ensembl/ENSMUSG00000020553
# ensembl/ENSMUSG00000022215
# ensembl/ENSMUSG00000022861
# ensembl/ENSMUSG00000023452
# ensembl/ENSMUSG00000024091
# ensembl/ENSMUSG00000024197
# ensembl/ENSMUSG00000025357
# ensembl/ENSMUSG00000025495
# ensembl/ENSMUSG00000026922
# ensembl/ENSMUSG00000027784
# ensembl/ENSMUSG00000032540
# ensembl/ENSMUSG00000034254
# ensembl/ENSMUSG00000036095
# ensembl/ENSMUSG00000036151
# ensembl/ENSMUSG00000048486
# ensembl/ENSMUSG00000052396
# ensembl/ENSMUSG00000054455
# ensembl/ENSMUSG00000071657
#
# ensembl/ENSMUSG00000032193

# %%
ensembl_trans
# Out:
# 'Eensembl/Nensembl/Sensembl/Mensembl/Uensembl/Sensembl/Tensembl/0ensembl/0ensembl/0ensembl/0ensembl/0ensembl/1ensembl/7ensembl/1ensembl/9ensembl/9ensembl/9'

# %%
ginfo[0]['ensembl']
# Out:
# {'gene': 'ENSMUSG00000000088',
#  'protein': 'ENSMUSP00000000090',
#  'transcript': ['ENSMUST00000000090',
#   'ENSMUST00000213678',
#   'ENSMUST00000214154'],
#  'translation': [{'protein': 'ENSMUSP00000000090',
#    'rna': 'ENSMUST00000000090'}],
#  'type_of_gene': 'protein_coding'}

# %%
MMRN_rxns = pd.read_excel('data/models/xlsx/MMRN.xlsx',sheet_name='RXNS',index_col='ID')

# %%
for index,row in MMRN_rxns.iterrows():
    if str(row['MIRIAM']) != 'nan':
        miriams = row['MIRIAM'].split(';')
        for item in miriams:
            parts = item.split('/')
            print(parts)
            MMRN_rxns.at[index,parts[0]] = parts[1]
# Out:
# ['vmhreaction', 'RE2649C']
# ['rhea', '40104']
# ['rhea', '40103']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0189']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0193']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0197']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0201']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0206']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0210']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0214']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01274']
# ['vmhreaction', 'HDCAc']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0230']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0234']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0238']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0242']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0246']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08174']
# ['vmhreaction', 'RE0344C']
# ['metanetx.reaction', 'MNXR99133']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0256']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0260']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'FACOAE181']
# ['vmhreaction', 'RE3245C']
# ['metanetx.reaction', 'MNXR99134']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0268']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0272']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0276']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0280']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08175']
# ['vmhreaction', 'RE0577C']
# ['metanetx.reaction', 'MNXR103462']
# ['rhea', '40148']
# ['rhea', '40147']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0290']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08186']
# ['vmhreaction', 'RE3238C']
# ['metanetx.reaction', 'MNXR103844']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0298']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0302']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0306']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0310']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08184']
# ['vmhreaction', 'RE0578C']
# ['metanetx.reaction', 'MNXR103463']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08187']
# ['vmhreaction', 'RE3239C']
# ['metanetx.reaction', 'MNXR103845']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0324']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0328']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08185']
# ['vmhreaction', 'RE0579C']
# ['metanetx.reaction', 'MNXR103464']
# ['metanetx.reaction', 'MNXR111757']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08188']
# ['vmhreaction', 'RE3237C']
# ['metanetx.reaction', 'MNXR103843']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0342']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0346']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08178']
# ['vmhreaction', 'HMR_0350']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0354']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0358']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08179']
# ['vmhreaction', 'HMR_0362']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08189']
# ['vmhreaction', 'HMR_0366']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0370']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0374']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08180']
# ['vmhreaction', 'HMR_0378']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08192']
# ['vmhreaction', 'HMR_0382']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0386']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0390']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0394']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08177']
# ['vmhreaction', 'HMR_0398']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08181']
# ['vmhreaction', 'HMR_0402']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08182']
# ['vmhreaction', 'HMR_0406']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08183']
# ['vmhreaction', 'HMR_0410']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08191']
# ['vmhreaction', 'HMR_0414']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0418']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0422']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0426']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08190']
# ['vmhreaction', 'HMR_0430']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08273']
# ['vmhreaction', 'HMR_0434']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0438']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2649X']
# ['metanetx.reaction', 'MNXR103712']
# ['rhea', '40104']
# ['rhea', '40103']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00227']
# ['reactome', 'R-HSA-390304']
# ['vmhreaction', 'HMR_3475']
# ['metanetx.reaction', 'MNXR95363']
# ['rhea', '20290']
# ['rhea', '20289']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00521']
# ['reactome', 'R-HSA-389580']
# ['vmhreaction', 'HMR_3476']
# ['metanetx.reaction', 'MNXR99473']
# ['rhea', '19742']
# ['rhea', '19741']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00521']
# ['vmhreaction', 'FCOAH']
# ['metanetx.reaction', 'MNXR99473']
# ['rhea', '19742']
# ['rhea', '19741']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00848']
# ['reactome', 'R-HSA-188467']
# ['vmhreaction', 'GLYC3PFADm']
# ['metanetx.reaction', 'MNXR99875']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00369']
# ['vmhreaction', 'AGTim']
# ['metanetx.reaction', 'MNXR95618']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00369']
# ['vmhreaction', 'AGTix']
# ['metanetx.reaction', 'MNXR95618']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01954']
# ['bigg.reaction', 'ARGSS']
# ['vmhreaction', 'ARGSS']
# ['metanetx.reaction', 'MNXR95949']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00485']
# ['bigg.reaction', 'ASNNm']
# ['vmhreaction', 'ASNNm']
# ['metanetx.reaction', 'MNXR96056']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00578']
# ['bigg.reaction', 'ASNS1']
# ['vmhreaction', 'ASNS1']
# ['metanetx.reaction', 'MNXR96059']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00355']
# ['bigg.reaction', 'ASPTAm']
# ['vmhreaction', 'ASPTAm']
# ['metanetx.reaction', 'MNXR96079']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00359']
# ['bigg.reaction', 'DASPO1p']
# ['vmhreaction', 'DASPO1p']
# ['metanetx.reaction', 'MNXR97153']
# ['rhea', '12513']
# ['rhea', '12512']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00488']
# ['bigg.reaction', 'NACASPAH']
# ['vmhreaction', 'NACASPAH']
# ['metanetx.reaction', 'MNXR101806']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2031M']
# ['metanetx.reaction', 'MNXR103592']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00401']
# ['bigg.reaction', 'ALAR']
# ['vmhreaction', 'ALAR']
# ['metanetx.reaction', 'MNXR95693']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00355']
# ['bigg.reaction', 'ASPTA']
# ['vmhreaction', 'ASPTA']
# ['metanetx.reaction', 'MNXR96079']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00485']
# ['vmhreaction', 'r0127']
# ['metanetx.reaction', 'MNXR96056']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01086']
# ['bigg.reaction', 'ARGSL']
# ['vmhreaction', 'ARGSL']
# ['metanetx.reaction', 'MNXR95948']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00243']
# ['bigg.reaction', 'GDHm']
# ['vmhreaction', 'GLUDxm']
# ['metanetx.reaction', 'MNXR100085']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00248']
# ['bigg.reaction', 'GLUDym']
# ['vmhreaction', 'GLUDym']
# ['metanetx.reaction', 'MNXR100086']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01954']
# ['bigg.reaction', 'ARGSS']
# ['vmhreaction', 'ARGSS']
# ['metanetx.reaction', 'MNXR95949']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00490']
# ['vmhreaction', 'HMR_3831']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00485']
# ['bigg.reaction', 'ASNNm']
# ['vmhreaction', 'ASNNm']
# ['metanetx.reaction', 'MNXR96056']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02619']
# ['bigg.reaction', '3SALATAim']
# ['vmhreaction', '3SALATAim']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00149']
# ['bigg.reaction', 'CPS']
# ['metanetx.reaction', 'MNXR96884']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'CBPter']
# ['vmhreaction', 'CBPSam']
# ['metanetx.reaction', 'MNXR96487']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00253']
# ['bigg.reaction', 'GLNS']
# ['vmhreaction', 'GLNS']
# ['metanetx.reaction', 'MNXR100024']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00256']
# ['bigg.reaction', 'GLUNm']
# ['vmhreaction', 'GLUNm']
# ['metanetx.reaction', 'MNXR100030']
# ['rhea', '15890']
# ['rhea', '15889']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00256']
# ['bigg.reaction', 'GLUNm']
# ['vmhreaction', 'HMR_9802']
# ['metanetx.reaction', 'MNXR100030']
# ['rhea', '15890']
# ['rhea', '15889']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00258']
# ['bigg.reaction', 'ALATA_L']
# ['vmhreaction', 'ALATA_L']
# ['metanetx.reaction', 'MNXR95698']
# ['rhea', '19456']
# ['rhea', '19453']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00578']
# ['bigg.reaction', 'ASNS1']
# ['vmhreaction', 'ASNS1']
# ['metanetx.reaction', 'MNXR96059']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00258']
# ['vmhreaction', 'r0081']
# ['metanetx.reaction', 'MNXR95698']
# ['rhea', '19456']
# ['rhea', '19453']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00269']
# ['vmhreaction', 'r0085']
# ['metanetx.reaction', 'MNXR105306']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00269']
# ['vmhreaction', 'r0086']
# ['metanetx.reaction', 'MNXR105306']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00485']
# ['vmhreaction', 'r0127']
# ['metanetx.reaction', 'MNXR96056']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00576']
# ['vmhreaction', 'r0156']
# ['metanetx.reaction', 'MNXR105309']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00576']
# ['vmhreaction', 'r0157']
# ['metanetx.reaction', 'MNXR105309']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00713']
# ['vmhreaction', 'r0178']
# ['metanetx.reaction', 'MNXR104540']
# ['rhea', '13218']
# ['rhea', '13217']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00261']
# ['bigg.reaction', 'GLUDC']
# ['vmhreaction', 'GLUDC']
# ['metanetx.reaction', 'MNXR95942']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2032M']
# ['metanetx.reaction', 'MNXR103593']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2034C']
# ['metanetx.reaction', 'MNXR103594']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2040C']
# ['metanetx.reaction', 'MNXR103595']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2041C']
# ['metanetx.reaction', 'MNXR103596']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00359']
# ['bigg.reaction', 'DASPO1p']
# ['vmhreaction', 'DASPO1p']
# ['metanetx.reaction', 'MNXR97153']
# ['rhea', '12513']
# ['rhea', '12512']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00487']
# ['bigg.reaction', 'ASPNATm']
# ['vmhreaction', 'ASPNATm']
# ['metanetx.reaction', 'MNXR96087']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R06728']
# ['bigg.reaction', 'COQ3m']
# ['vmhreaction', 'COKECBESr']
# ['metanetx.reaction', 'MNXR96850']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'r1374']
# ['metanetx.reaction', 'MNXR105461']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00022']
# ['vmhreaction', 'r0013']
# ['metanetx.reaction', 'MNXR100746']
# ['metanetx.reaction', 'MNXR95628']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01384']
# ['bigg.reaction', 'UDPGLDCg']
# ['vmhreaction', 'HMR_4124']
# ['metanetx.reaction', 'MNXR105068']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00415']
# ['bigg.reaction', 'UAGDP']
# ['vmhreaction', 'UAGDP']
# ['metanetx.reaction', 'MNXR105033']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00765']
# ['bigg.reaction', 'G6PDA']
# ['vmhreaction', 'G6PDA']
# ['metanetx.reaction', 'MNXR99905']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01961']
# ['bigg.reaction', 'HEX10']
# ['vmhreaction', 'HEX10']
# ['metanetx.reaction', 'MNXR100613']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01201']
# ['bigg.reaction', 'ACGAMK']
# ['vmhreaction', 'ACGAMK']
# ['metanetx.reaction', 'MNXR95249']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00414']
# ['vmhreaction', 'r0113']
# ['metanetx.reaction', 'MNXR105025']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00414']
# ['bigg.reaction', 'UAG2EMA']
# ['vmhreaction', 'UAG2EMAi']
# ['metanetx.reaction', 'MNXR105025']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02705']
# ['bigg.reaction', 'AMANK']
# ['vmhreaction', 'AMANK']
# ['metanetx.reaction', 'MNXR95805']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R04435']
# ['bigg.reaction', 'ACNAM9PL']
# ['vmhreaction', 'ACNAM9PL']
# ['metanetx.reaction', 'MNXR108888']
# ['metanetx.reaction', 'MNXR95288']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01805']
# ['bigg.reaction', 'ACNAMPH']
# ['vmhreaction', 'ACNAMPH']
# ['metanetx.reaction', 'MNXR107181']
# ['metanetx.reaction', 'MNXR95290']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01803']
# ['vmhreaction', 'HMR_4531']
# ['vmhreaction', 'r0400']
# ['metanetx.reaction', 'MNXR105335']
# ['metanetx.reaction', 'MNXR107180']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01115']
# ['vmhreaction', 'r0267']
# ['metanetx.reaction', 'MNXR105317']
# ['metanetx.reaction', 'MNXR106831']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01117']
# ['bigg.reaction', 'CMPSASn']
# ['vmhreaction', 'CMPSASn']
# ['metanetx.reaction', 'MNXR95295']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02058']
# ['bigg.reaction', 'ACGAM6PS']
# ['vmhreaction', 'ACGAM6PSi']
# ['metanetx.reaction', 'MNXR95248']
# ['rhea', '10293']
# ['rhea', '10292']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02059']
# ['bigg.reaction', 'AGDC']
# ['vmhreaction', 'AGDC']
# ['metanetx.reaction', 'MNXR95528']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02328']
# ['bigg.reaction', 'G1PTT']
# ['vmhreaction', 'G1PTT']
# ['metanetx.reaction', 'MNXR99846']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R06513']
# ['bigg.reaction', 'TDPGDH']
# ['vmhreaction', 'TDPGDH']
# ['metanetx.reaction', 'MNXR104761']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02984']
# ['vmhreaction', 'HMR_7698']
# ['metanetx.reaction', 'MNXR107867']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'ACGALK']
# ['vmhreaction', 'ACGALK']
# ['metanetx.reaction', 'MNXR95241']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'ACGALK2']
# ['vmhreaction', 'ACGALK2']
# ['metanetx.reaction', 'MNXR95242']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R10183']
# ['bigg.reaction', 'UAGALDP']
# ['vmhreaction', 'UAGALDP']
# ['metanetx.reaction', 'MNXR105031']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'ACNAM9PL2']
# ['vmhreaction', 'ACNAM9PL2']
# ['metanetx.reaction', 'MNXR95289']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'KDNH']
# ['vmhreaction', 'KDNH']
# ['metanetx.reaction', 'MNXR100931']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01811']
# ['bigg.reaction', 'ACNML']
# ['vmhreaction', 'ACNMLr']
# ['metanetx.reaction', 'MNXR95296']
# ['rhea', '23299']
# ['rhea', '23296']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00022']
# ['bigg.reaction', 'CHTNASEe']
# ['vmhreaction', 'CHTNASE']
# ['metanetx.reaction', 'MNXR96717']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00022']
# ['bigg.reaction', 'CITL']
# ['vmhreaction', 'CHTNASEe']
# ['metanetx.reaction', 'MNXR96731']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01117']
# ['bigg.reaction', 'CMPSASn']
# ['vmhreaction', 'CMPSAS']
# ['metanetx.reaction', 'MNXR95295']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01384']
# ['bigg.reaction', 'UDPGLDCg']
# ['vmhreaction', 'UDPGLDCg']
# ['metanetx.reaction', 'MNXR105068']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R06514']
# ['bigg.reaction', 'TDPDRE']
# ['vmhreaction', 'TDPDRE']
# ['metanetx.reaction', 'MNXR104759']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02777']
# ['bigg.reaction', 'TDPDRR']
# ['vmhreaction', 'TDPDRR']
# ['metanetx.reaction', 'MNXR104760']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02918']
# ['vmhreaction', 'HMR_5130']
# ['metanetx.reaction', 'MNXR105001']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03038']
# ['vmhreaction', 'HMR_5131']
# ['metanetx.reaction', 'MNXR107903']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03646']
# ['vmhreaction', 'HMR_5132']
# ['metanetx.reaction', 'MNXR95950']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03648']
# ['vmhreaction', 'HMR_5133']
# ['metanetx.reaction', 'MNXR96064']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R05577']
# ['vmhreaction', 'HMR_5134']
# ['metanetx.reaction', 'MNXR96101']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03650']
# ['vmhreaction', 'HMR_5135']
# ['metanetx.reaction', 'MNXR97018']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03652']
# ['vmhreaction', 'HMR_5136']
# ['metanetx.reaction', 'MNXR100257']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R05578']
# ['vmhreaction', 'HMR_5137']
# ['metanetx.reaction', 'MNXR100295']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03654']
# ['vmhreaction', 'HMR_5138']
# ['metanetx.reaction', 'MNXR100365']
# ['rhea', '16014']
# ['rhea', '16013']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03655']
# ['vmhreaction', 'HMR_5139']
# ['metanetx.reaction', 'MNXR100643']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03656']
# ['vmhreaction', 'HMR_5140']
# ['metanetx.reaction', 'MNXR100820']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03657']
# ['vmhreaction', 'HMR_5141']
# ['metanetx.reaction', 'MNXR101053']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03658']
# ['vmhreaction', 'HMR_5142']
# ['metanetx.reaction', 'MNXR101264']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03659']
# ['vmhreaction', 'HMR_5143']
# ['metanetx.reaction', 'MNXR101488']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03940']
# ['vmhreaction', 'HMR_5144']
# ['metanetx.reaction', 'MNXR99604']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03660']
# ['vmhreaction', 'HMR_5145']
# ['metanetx.reaction', 'MNXR102634']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03661']
# ['vmhreaction', 'HMR_5146']
# ['metanetx.reaction', 'MNXR103208']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03662']
# ['vmhreaction', 'HMR_5147']
# ['metanetx.reaction', 'MNXR104350']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03663']
# ['vmhreaction', 'HMR_5148']
# ['metanetx.reaction', 'MNXR104848']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03664']
# ['vmhreaction', 'HMR_5149']
# ['metanetx.reaction', 'MNXR104948']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03665']
# ['vmhreaction', 'HMR_5150']
# ['metanetx.reaction', 'MNXR105186']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02058']
# ['bigg.reaction', 'ACGAM6PS']
# ['vmhreaction', 'ACGAM6PSi']
# ['metanetx.reaction', 'MNXR95248']
# ['rhea', '10293']
# ['rhea', '10292']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01201']
# ['bigg.reaction', 'ACGAMK']
# ['vmhreaction', 'ACGAMK']
# ['metanetx.reaction', 'MNXR95249']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02086']
# ['bigg.reaction', 'ACGAMPM']
# ['vmhreaction', 'ACGAMPM']
# ['metanetx.reaction', 'MNXR95250']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01961']
# ['bigg.reaction', 'HEX10']
# ['vmhreaction', 'HEX10']
# ['metanetx.reaction', 'MNXR100613']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00414']
# ['bigg.reaction', 'UAG2EMA']
# ['vmhreaction', 'UAG2EMAi']
# ['metanetx.reaction', 'MNXR105025']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00414']
# ['vmhreaction', 'r0113']
# ['metanetx.reaction', 'MNXR105025']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01964']
# ['vmhreaction', 'r0363']
# ['metanetx.reaction', 'MNXR105330']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01965']
# ['vmhreaction', 'r0364']
# ['metanetx.reaction', 'MNXR105331']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00768']
# ['bigg.reaction', 'GF6PTA']
# ['vmhreaction', 'GF6PTA']
# ['metanetx.reaction', 'MNXR100107']
# ['metanetx.reaction', 'MNXR106675']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00418']
# ['bigg.reaction', 'UAG4E']
# ['vmhreaction', 'UAG4E']
# ['metanetx.reaction', 'MNXR105026']
# ['metanetx.reaction', 'MNXR105027']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00415']
# ['bigg.reaction', 'UAGDP']
# ['vmhreaction', 'UAGDP']
# ['metanetx.reaction', 'MNXR105033']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02705']
# ['bigg.reaction', 'AMANK']
# ['vmhreaction', 'AMANK']
# ['metanetx.reaction', 'MNXR95805']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00765']
# ['bigg.reaction', 'G6PDA']
# ['vmhreaction', 'G6PDA']
# ['metanetx.reaction', 'MNXR99905']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01207']
# ['bigg.reaction', 'ACGAM2E']
# ['vmhreaction', 'ACGAM2E']
# ['metanetx.reaction', 'MNXR95247']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1635M']
# ['metanetx.reaction', 'MNXR103529']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1635X']
# ['metanetx.reaction', 'MNXR103529']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1815M']
# ['metanetx.reaction', 'MNXR103548']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1815X']
# ['metanetx.reaction', 'MNXR103548']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1816M']
# ['metanetx.reaction', 'MNXR103549']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1816X']
# ['metanetx.reaction', 'MNXR103549']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1817M']
# ['metanetx.reaction', 'MNXR103550']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1817X']
# ['metanetx.reaction', 'MNXR103550']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2318M']
# ['metanetx.reaction', 'MNXR103650']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2318X']
# ['metanetx.reaction', 'MNXR103650']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2319M']
# ['metanetx.reaction', 'MNXR103651']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2319X']
# ['metanetx.reaction', 'MNXR103651']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_2062']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_2077']
# ['sbo', 'SBO:0000176']
# ['reactome', 'R-HSA-193068']
# ['vmhreaction', 'HMR_1944']
# ['metanetx.reaction', 'MNXR124741']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'P45017A1r']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08978']
# ['vmhreaction', 'PRGNLONESULT']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08942']
# ['vmhreaction', 'RE1135C']
# ['metanetx.reaction', 'MNXR104608']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08516']
# ['reactome', 'R-HSA-193070']
# ['vmhreaction', 'HMR_1958']
# ['metanetx.reaction', 'MNXR124742']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1134C']
# ['metanetx.reaction', 'MNXR102255']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1134R']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1962']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1099C']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R09957']
# ['vmhreaction', 'HMR_1967']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R09957']
# ['vmhreaction', 'HMR_1968']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03405']
# ['vmhreaction', 'DHEASULT']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1970']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1971']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01838']
# ['reactome', 'R-HSA-193064']
# ['vmhreaction', 'RE2766C']
# ['metanetx.reaction', 'MNXR100717']
# ['metanetx.reaction', 'MNXR107199']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01838']
# ['vmhreaction', 'HSD17B3r']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02497']
# ['reactome', 'R-HSA-469659']
# ['vmhreaction', 'HMR_1976']
# ['metanetx.reaction', 'MNXR107543']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02497']
# ['reactome', 'R-HSA-469659']
# ['vmhreaction', 'SR5ARr']
# ['metanetx.reaction', 'MNXR107543']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R04344']
# ['vmhreaction', 'RE3108C']
# ['metanetx.reaction', 'MNXR103791']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03327']
# ['reactome', 'R-HSA-196372']
# ['vmhreaction', 'HMR_1982']
# ['metanetx.reaction', 'MNXR123730']
# ['sbo', 'SBO:0000176']
# ['reactome', 'R-HSA-193961']
# ['vmhreaction', 'HMR_1983']
# ['metanetx.reaction', 'MNXR124765']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R10242']
# ['vmhreaction', 'HMR_2014']
# ['metanetx.reaction', 'MNXR107196']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R10242']
# ['vmhreaction', 'SR5AR2r']
# ['metanetx.reaction', 'MNXR107195']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02476']
# ['vmhreaction', 'HMR_2016']
# ['metanetx.reaction', 'MNXR107533']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02477']
# ['vmhreaction', 'HMR_2018']
# ['metanetx.reaction', 'MNXR107534']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3220C']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3111C']
# ['metanetx.reaction', 'MNXR103793']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3111R']
# ['metanetx.reaction', 'MNXR103793']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3218C']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1952C']
# ['metanetx.reaction', 'MNXR103586']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1952R']
# ['metanetx.reaction', 'MNXR103586']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1952X']
# ['metanetx.reaction', 'MNXR103586']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1956C']
# ['metanetx.reaction', 'MNXR103588']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1956R']
# ['metanetx.reaction', 'MNXR103588']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE1956X']
# ['metanetx.reaction', 'MNXR103588']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE2048N']
# ['vmhreaction', 'RE2048N']
# ['metanetx.reaction', 'MNXR103597']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07043']
# ['vmhreaction', 'RE3036C']
# ['metanetx.reaction', 'MNXR103778']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07032']
# ['vmhreaction', 'RE3038C']
# ['metanetx.reaction', 'MNXR103779']
# ['metanetx.reaction', 'MNXR110744']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07032']
# ['vmhreaction', 'RE3038R']
# ['metanetx.reaction', 'MNXR103779']
# ['metanetx.reaction', 'MNXR110744']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07032']
# ['vmhreaction', 'RE3038X']
# ['metanetx.reaction', 'MNXR103779']
# ['metanetx.reaction', 'MNXR110744']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07031']
# ['vmhreaction', 'RE3040C']
# ['metanetx.reaction', 'MNXR103780']
# ['metanetx.reaction', 'MNXR110743']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07031']
# ['vmhreaction', 'RE3040R']
# ['metanetx.reaction', 'MNXR103780']
# ['metanetx.reaction', 'MNXR110743']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07031']
# ['vmhreaction', 'RE3040X']
# ['metanetx.reaction', 'MNXR103780']
# ['metanetx.reaction', 'MNXR110743']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3044N']
# ['metanetx.reaction', 'MNXR103782']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3287R']
# ['vmhreaction', 'RE3287R']
# ['metanetx.reaction', 'MNXR103863']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3470C']
# ['vmhreaction', 'RE3470C']
# ['metanetx.reaction', 'MNXR103916']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3470M']
# ['vmhreaction', 'RE3470M']
# ['metanetx.reaction', 'MNXR103916']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3470X']
# ['vmhreaction', 'RE3470X']
# ['metanetx.reaction', 'MNXR103916']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3474R']
# ['vmhreaction', 'RE3474R']
# ['metanetx.reaction', 'MNXR103917']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3475N']
# ['vmhreaction', 'RE3475N']
# ['metanetx.reaction', 'MNXR103918']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3476C']
# ['metanetx.reaction', 'MNXR103919']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3476M']
# ['vmhreaction', 'RE3476M']
# ['metanetx.reaction', 'MNXR103919']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3476X']
# ['vmhreaction', 'RE3476X']
# ['metanetx.reaction', 'MNXR103919']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3513N']
# ['vmhreaction', 'RE3513N']
# ['metanetx.reaction', 'MNXR103939']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3514R']
# ['vmhreaction', 'RE3514R']
# ['metanetx.reaction', 'MNXR103940']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3519C']
# ['metanetx.reaction', 'MNXR103943']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3519R']
# ['metanetx.reaction', 'MNXR103943']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3519X']
# ['metanetx.reaction', 'MNXR103943']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07039']
# ['vmhreaction', 'RE3520E']
# ['metanetx.reaction', 'MNXR103944']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3521M']
# ['vmhreaction', 'RE3521M']
# ['metanetx.reaction', 'MNXR103945']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3521X']
# ['metanetx.reaction', 'MNXR103945']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3525C']
# ['metanetx.reaction', 'MNXR103948']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'RE3526C']
# ['vmhreaction', 'RE3526C']
# ['metanetx.reaction', 'MNXR103949']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01596']
# ['vmhreaction', 'HMR_1030']
# ['metanetx.reaction', 'MNXR107078']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0931']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0932']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0933']
# ['sbo', 'SBO:0000176']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0935']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0936']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07054']
# ['vmhreaction', 'HMR_0937']
# ['metanetx.reaction', 'MNXR110764']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0938']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0939']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07046']
# ['vmhreaction', 'HMR_0940']
# ['metanetx.reaction', 'MNXR110756']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07041']
# ['metanetx.reaction', 'MNXR110751']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07052']
# ['vmhreaction', 'HMR_0942']
# ['metanetx.reaction', 'MNXR110762']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3286C']
# ['metanetx.reaction', 'MNXR103862']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3286R']
# ['metanetx.reaction', 'MNXR103862']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07111']
# ['vmhreaction', 'HMR_0945']
# ['metanetx.reaction', 'MNXR110819']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07051']
# ['vmhreaction', 'HMR_0946']
# ['metanetx.reaction', 'MNXR110761']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3288C']
# ['metanetx.reaction', 'MNXR103864']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3288R']
# ['metanetx.reaction', 'MNXR103864']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07110']
# ['vmhreaction', 'HMR_0949']
# ['metanetx.reaction', 'MNXR110818']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07050']
# ['vmhreaction', 'HMR_0950']
# ['metanetx.reaction', 'MNXR110760']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3287C']
# ['metanetx.reaction', 'MNXR103863']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07109']
# ['vmhreaction', 'HMR_0953']
# ['metanetx.reaction', 'MNXR110817']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07048']
# ['vmhreaction', 'HMR_0954']
# ['metanetx.reaction', 'MNXR110758']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3289C']
# ['metanetx.reaction', 'MNXR103865']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3289R']
# ['metanetx.reaction', 'MNXR103865']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07108']
# ['vmhreaction', 'HMR_0957']
# ['metanetx.reaction', 'MNXR110816']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01595']
# ['reactome', 'R-HSA-265296']
# ['vmhreaction', 'ALOX5']
# ['metanetx.reaction', 'MNXR124874']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R03058']
# ['reactome', 'R-HSA-266051']
# ['vmhreaction', 'ALOX52']
# ['metanetx.reaction', 'MNXR107920']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07034']
# ['vmhreaction', 'HMR_0960']
# ['metanetx.reaction', 'MNXR110745']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07034']
# ['vmhreaction', 'HMR_0963']
# ['metanetx.reaction', 'MNXR110745']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3525C']
# ['metanetx.reaction', 'MNXR103948']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3525M']
# ['metanetx.reaction', 'MNXR103948']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3525R']
# ['metanetx.reaction', 'MNXR103948']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3474C']
# ['metanetx.reaction', 'MNXR103917']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3475C']
# ['metanetx.reaction', 'MNXR103918']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3476C']
# ['metanetx.reaction', 'MNXR103919']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0981']
# ['metanetx.reaction', 'MNXR103940']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01593']
# ['vmhreaction', 'ALOX15']
# ['metanetx.reaction', 'MNXR107075']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01593']
# ['vmhreaction', 'HMR_0985']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01593']
# ['vmhreaction', 'HMR_0986']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01593']
# ['vmhreaction', 'HMR_0987']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07035']
# ['vmhreaction', 'HMR_0988']
# ['metanetx.reaction', 'MNXR110746']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R04517']
# ['vmhreaction', 'HMR_0990']
# ['metanetx.reaction', 'MNXR108941']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07042']
# ['vmhreaction', 'HMR_0991']
# ['metanetx.reaction', 'MNXR110752']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07044']
# ['vmhreaction', 'HMR_0992']
# ['metanetx.reaction', 'MNXR110754']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07043']
# ['vmhreaction', 'HMR_0993']
# ['metanetx.reaction', 'MNXR110753']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07045']
# ['vmhreaction', 'HMR_0994']
# ['metanetx.reaction', 'MNXR110755']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0995']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0996']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0997']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0998']
# ['metanetx.reaction', 'MNXR103597']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_0999']
# ['metanetx.reaction', 'MNXR103597']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE2048R']
# ['metanetx.reaction', 'MNXR103597']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07043']
# ['vmhreaction', 'RE3036N']
# ['metanetx.reaction', 'MNXR103778']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3044C']
# ['metanetx.reaction', 'MNXR103782']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3044N']
# ['metanetx.reaction', 'MNXR103782']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3033C']
# ['metanetx.reaction', 'MNXR103777']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3033N']
# ['metanetx.reaction', 'MNXR103777']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3033R']
# ['metanetx.reaction', 'MNXR103777']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1018']
# ['metanetx.reaction', 'MNXR103777']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07032']
# ['vmhreaction', 'RE3038N']
# ['metanetx.reaction', 'MNXR103779']
# ['metanetx.reaction', 'MNXR110744']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07031']
# ['vmhreaction', 'HMR_1026']
# ['metanetx.reaction', 'MNXR110743']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01596']
# ['vmhreaction', 'ALOX12']
# ['metanetx.reaction', 'MNXR107078']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01596']
# ['vmhreaction', 'HMR_1033']
# ['metanetx.reaction', 'MNXR107078']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01596']
# ['vmhreaction', 'HMR_1034']
# ['metanetx.reaction', 'MNXR107078']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1037']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1039']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1040']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07040']
# ['vmhreaction', 'HMR_1041']
# ['metanetx.reaction', 'MNXR110750']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07037']
# ['vmhreaction', 'HMR_1042']
# ['metanetx.reaction', 'MNXR110747']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07039']
# ['vmhreaction', 'RE3520C']
# ['metanetx.reaction', 'MNXR103944']
# ['metanetx.reaction', 'MNXR110749']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07039']
# ['vmhreaction', 'HMR_1048']
# ['metanetx.reaction', 'MNXR103944']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07039']
# ['vmhreaction', 'HMR_1049']
# ['metanetx.reaction', 'MNXR103944']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3521C']
# ['metanetx.reaction', 'MNXR103945']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3521R']
# ['metanetx.reaction', 'MNXR103945']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3518C']
# ['metanetx.reaction', 'MNXR103942']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3518R']
# ['metanetx.reaction', 'MNXR103942']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07053']
# ['vmhreaction', 'HMR_1062']
# ['metanetx.reaction', 'MNXR110763']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1063']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R07047']
# ['vmhreaction', 'HMR_1064']
# ['metanetx.reaction', 'MNXR110757']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1065']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1066']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1067']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1068']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1069']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1070']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3522C']
# ['metanetx.reaction', 'MNXR103946']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3522R']
# ['metanetx.reaction', 'MNXR103946']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1073']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1074']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'RE3513C']
# ['metanetx.reaction', 'MNXR103939']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1077']
# ['vmhreaction', 'RE3513R']
# ['metanetx.reaction', 'MNXR103939']
# ['sbo', 'SBO:0000176']
# ['vmhreaction', 'HMR_1079']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R08183']
# ['vmhreaction', 'r0308']
# ['metanetx.reaction', 'MNXR105320']
# ['metanetx.reaction', 'MNXR99131']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R05051']
# ['bigg.reaction', '4HGLSDm']
# ['vmhreaction', '4HGLSDm']
# ['metanetx.reaction', 'MNXR95015']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R04025']
# ['bigg.reaction', 'APRTO2']
# ['vmhreaction', 'APRTO2']
# ['metanetx.reaction', 'MNXR95900']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00566']
# ['bigg.reaction', 'ARGDCm']
# ['vmhreaction', 'ARGDCm']
# ['metanetx.reaction', 'MNXR95940']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02923']
# ['bigg.reaction', 'DASCBH']
# ['vmhreaction', 'DARGOp']
# ['metanetx.reaction', 'MNXR97151']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R02457']
# ['bigg.reaction', 'DPCOAPP']
# ['vmhreaction', 'DORNOp']
# ['metanetx.reaction', 'MNXR97763']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'DPROOp']
# ['vmhreaction', 'DPROOp']
# ['metanetx.reaction', 'MNXR97780']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R05053']
# ['bigg.reaction', 'EICOSTETCPT1']
# ['vmhreaction', 'EHGLAT2m']
# ['metanetx.reaction', 'MNXR109293']
# ['metanetx.reaction', 'MNXR97910']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R05052']
# ['vmhreaction', 'EHGLATm']
# ['metanetx.reaction', 'MNXR109292']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R05050']
# ['bigg.reaction', 'NABTNO']
# ['vmhreaction', 'NABTNO']
# ['metanetx.reaction', 'MNXR101805']
# ['sbo', 'SBO:0000176']
# ['bigg.reaction', 'NABTNOm']
# ['vmhreaction', 'NABTNOm']
# ['metanetx.reaction', 'MNXR101805']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00558']
# ['bigg.reaction', 'NOS1']
# ['vmhreaction', 'NOS1']
# ['metanetx.reaction', 'MNXR102006']
# ['metanetx.reaction', 'MNXR106582']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R00111']
# ['bigg.reaction', 'NOS2']
# ['vmhreaction', 'NOS2']
# ['vmhreaction', 'r0024']
# ['metanetx.reaction', 'MNXR102007']
# ['metanetx.reaction', 'MNXR106395']
# ['sbo', 'SBO:0000176']
# ['kegg.reaction', 'R01251']
# ['bigg.reaction', 'P5CRm']
# ['vmhreaction', 'P5CRm']
# ['metanetx.reaction', 'MNXR102302']
# ['sbo', 'SBO:0000176']
# ['rxnBiGGID\nPRO1xm    kegg.reaction', 'R01248']
# ['bigg.reaction', 'PRO1xm']
# ['vmhr...\nPRO1xm    kegg.reaction', 'R01248']
# ['bigg.reaction', 'PRO1xm']
# ['vmhr...\nName: MIRIAM, dtype: object']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/zc/h_66z5bx601_njjc__92xndnxk18rv/T/ipykernel_68754/1400251006.py in <module>
#       5             parts = item.split('/')
#       6             print(parts)
# ----> 7             MMRN_rxns.at[index,parts[0]] = parts[1]
#
# IndexError: list index out of range
